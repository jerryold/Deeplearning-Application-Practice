# %%
import tensorflow as tf
import cv2
import os 
import matplotlib.pyplot as plt
import numpy as np

# %%
path = os.getcwd()
a_test = os.path.join(path, "train/0/Training_3908.jpg")

# %%
img_array=cv2.imread(a_test)
plt.imshow(img_array)

# %%
img_array.shape
# Out:
# (48, 48, 3)

# %%
trainpath = os.path.join(path, "train/")

# %%
Classes=["0","1","2","3","4","5","6"]

# %%
for category in Classes:
    path=os.path.join(trainpath, category)
    for img in os.listdir(path):
        img_array=cv2.imread(os.path.join(path,img))
        plt.imshow(cv2.cvtColor(img_array,cv2.COLOR_BGR2RGB))
        plt.show()
        break
    break

# %%
img_size=224 ##ImageNet->224*224
new_array=cv2.resize(img_array,(img_size,img_size))
plt.imshow(cv2.cvtColor(new_array,cv2.COLOR_BGR2RGB))
plt.show()

# %%
new_array.shape
# Out:
# (224, 224, 3)

# %% [markdown]
# # read all the images and convert in them to array

# %%
training_Data=[] #Data

def create_training_Data():
    for category in Classes:
        path=os.path.join(trainpath, category)
        class_num=Classes.index(category) ## 0,1 ##label
        for img in os.listdir(path):
            try:
                img_array=cv2.imread(os.path.join(path,img))
                new_array=cv2.resize(img_array,(img_size,img_size))
                training_Data.append([new_array,class_num])
            except Exception as e:
                pass

# %%
create_training_Data()

# %%
print(len(training_Data))
# Out:
# 28709

# %%
temp=np.array(training_Data)
# Out:
# C:\Users\jerryold\AppData\Local\Temp/ipykernel_21004/3867436754.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   temp=np.array(training_Data)

# %%
temp.shape
# Out:
# (28709, 2)

# %%
import random

random.shuffle(training_Data)

# %%
X=[]
Y=[]

for features,label in training_Data:
    X.append(features)
    Y.append(label)

X=np.array(X).reshape(-1,img_size,img_size,3) ##convert it to 4 dimension

# %%
X.shape
# Out:
# (28709, 224, 224, 3)

# %%
# normalize the data
X=X/255.0;## we are normaliing it

# %%
type(Y)
# Out:
# list

# %%
Y=np.array(Y)
Y.shape
# Out:
# (28709,)

# %% [markdown]
# # deeplearning model for training -Transfer learning

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
model =tf.keras.applications.MobileNetV2() ##Pre-trained Model

# %%
model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# ...

# %% [markdown]
# # Transfer learning -Tuning,weight will start from last check point

# %%
base_input=model.layers[0].input ##input

# %%
base_output=model.layers[-2].output #last second layer

# %%
base_output
# Out:
# <KerasTensor: shape=(None, 1280) dtype=float32 (created by layer 'global_average_pooling2d')>

# %%
final_output=layers.Dense(128)(base_output) ##adding new layer ,after the output of global pooling layer
final_ouput=layers.Activation('relu')(final_output) ##activation function
final_output=layers.Dense(64)(final_ouput) 
final_ouput=layers.Activation('relu')(final_output)
final_output=layers.Dense(7,activation='softmax')(final_ouput) ##my class are 0~7,classification layer

# %%
final_output ##output
# Out:
# <KerasTensor: shape=(None, 7) dtype=float32 (created by layer 'dense_2')>

# %%
new_model=keras.Model(inputs=base_input,outputs=final_output)

# %%
new_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# ...

# %%
new_model.compile(loss="sparse_categorical_crossentropy",optimizer="adam",metrics=["accuracy"]) #because we don't use one-hot encoding

# %%
X=np.zeros((28709, 224, 224, 3),dtype='uint8')
Y=np.zeros((28709,),dtype='uint8')

# %%
new_model.fit(X,Y,epochs=25)
# Out:
# Epoch 1/25
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21004/1823169060.py in <module>
# ----> 1 new_model.fit(X,Y,epochs=25)
#
# ~\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1181                 _r=1):
#    1182               callbacks.on_train_batch_begin(step)
# -> 1183               tmp_logs = self.train_function(iterator)
#    1184               if data_handler.should_sync:
#    1185                 context.async_wait()
#
# ...
