# %% [markdown]
# # 拍照，在按q之后，保存圖片並退出。

# %%
import cv2

cap=cv2.VideoCapture(0)
while True:
    #get a frame
    ret,frame=cap.read()
    #show a frame
    cv2.imshow("capture",frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        cv2.imwrite('sample.jpg',frame)
        break
        
cap.release()
cv2.destroyAllWindows()

# %%
import pixellib


from pixellib.instance import instance_segmentation
segment_image = instance_segmentation()
segment_image.load_model('mask_rcnn_coco.h5')
segment_image.segmentImage('sample.jpg', output_image_name = 'image_new.jpg', show_bboxes = True)
# Out:
# Processed image saved successfully in your current working directory.
# ({'rois': array([[326,  39, 429,  80],
#          [322, 453, 428, 564],
#          [276, 285, 362, 322],
#          [224, 154, 297, 179],
#          [255, 316, 325, 340],
#          [221, 180, 290, 199],
#          [206, 199, 272, 217],
#          [212, 129, 287, 158],
#          [296,  64, 355,  89],
#          [235, 422, 307, 505],
#          [195, 509, 259, 585],
#          [241, 572, 344, 681],
#          [198, 652, 260, 674],
#          [185, 625, 241, 643],
#          [ 82, 530, 115, 543],
#          [185, 108, 242, 127],
#          [138, 417, 202, 484],
#          [323, 292, 374, 314],
#          [181, 684, 290, 700],
#          [115, 190, 140, 203],
#          [ 89, 243, 132, 280],
#          [182, 146, 227, 167],
#          [212, 249, 281, 273],
#          [ 92, 549, 117, 560],
#          [ 21, 385,  51, 416],
#          [239, 243, 297, 269],
#          [ 50, 605, 128, 649],
#          [134, 626, 176, 642],
#          [ 86, 391, 122, 409],
#          [319,  42, 344,  61],
#          [ 87, 514, 120, 526],
#          [156, 167, 198, 181]]),
#   'class_ids': array([ 1,  3,  1,  1,  1,  1,  1,  1,  1,  3,  3,  3,  1,  1,  1,  1,  3,
#           2,  1, 10,  3,  1,  1,  1,  3,  2, 10,  1,  3,  1,  1,  1]),
#   'scores': array([0.9983454 , 0.9978854 , 0.99758685, 0.9972548 , 0.9961274 ,
#          0.99468404, 0.9922631 , 0.9917715 , 0.9893917 , 0.9877363 ,
#          0.9871579 , 0.983133  , 0.9721202 , 0.9698977 , 0.96807   ,
#          0.967694  , 0.9648461 , 0.9597482 , 0.95303464, 0.943639  ,
#          0.9425563 , 0.94232583, 0.92747396, 0.92372084, 0.92007184,
#          0.9108225 , 0.90255386, 0.88589275, 0.8283684 , 0.82141334,
#          0.8015361 , 0.7621268 ], dtype=float32),
#   'masks': array([[[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          ...,
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]]])},
#  array([[[ 80,  96,  89],
#          [ 72,  88,  81],
#          [ 73,  89,  82],
#          ...,
#          [118, 118, 118],
#          [116, 116, 116],
#          [115, 115, 115]],
#
#         [[ 45,  61,  54],
#          [ 56,  74,  67],
#          [ 72,  88,  81],
#          ...,
#          [118, 118, 118],
#          [116, 116, 116],
#          [115, 115, 115]],
#
#         [[ 25,  43,  36],
#          [ 40,  61,  53],
#          [ 60,  78,  71],
#          ...,
#          [118, 118, 118],
#          [116, 116, 116],
#          [115, 115, 115]],
#
#         ...,
#
#         [[137, 133, 114],
#          [143, 139, 120],
#          [125, 124, 104],
#          ...,
#          [114, 108, 113],
#          [113, 107, 112],
#          [111, 105, 110]],
#
#         [[ 67,  63,  44],
#          [ 99,  95,  76],
#          [124, 123, 103],
#          ...,
#          [108, 102, 107],
#          [106, 100, 105],
#          [105,  99, 104]],
#
#         [[ 52,  48,  29],
#          [ 88,  84,  65],
#          [118, 117,  97],
#          ...,
#          [108, 102, 107],
#          [106, 100, 105],
#          [105,  99, 104]]], dtype=uint8))

# %%
# 讀取產生後圖檔
img = cv2.imread('image_new.jpg')
# 顯示圖片
cv2.imshow('My Image', img)

# 按下任意鍵則關閉所有視窗
cv2.waitKey(0)
cv2.destroyAllWindows()
