# %%
import cv2

# %%
pip install deepface
# Out:
# Requirement already satisfied: deepface in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (0.0.68)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from deepface) (1.3.2)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from deepface) (3.13.0)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from deepface) (8.3.2)
# Requirement already satisfied: keras>=2.2.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from deepface) (2.6.0)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from deepface) (0.1.1)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from deepface) (2.0.1)
# Requirement already satisfied: opencv-python>=3.4.4 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from deepface) (4.5.3.56)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from deepface) (2.6.0)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from deepface) (4.62.2)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from deepface) (1.19.5)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from deepface) (0.0.5)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from Flask>=1.1.2->deepface) (2.0.1)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from Flask>=1.1.2->deepface) (2.0.1)
# Requirement already satisfied: click>=7.1.2 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from Flask>=1.1.2->deepface) (8.0.1)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from Flask>=1.1.2->deepface) (3.0.1)
# Requirement already satisfied: colorama in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from click>=7.1.2->Flask>=1.1.2->deepface) (0.4.4)
# Requirement already satisfied: importlib-metadata in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from click>=7.1.2->Flask>=1.1.2->deepface) (4.8.1)
# Requirement already satisfied: requests[socks]>=2.12.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from gdown>=3.10.1->deepface) (2.26.0)
# Requirement already satisfied: filelock in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from gdown>=3.10.1->deepface) (3.0.12)
# Requirement already satisfied: six in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from Jinja2>=3.0->Flask>=1.1.2->deepface) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from pandas>=0.23.4->deepface) (2021.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from requests[socks]>=2.12.0->gdown>=3.10.1->deepface) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from requests[socks]>=2.12.0->gdown>=3.10.1->deepface) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from requests[socks]>=2.12.0->gdown>=3.10.1->deepface) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from requests[socks]>=2.12.0->gdown>=3.10.1->deepface) (3.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from requests[socks]>=2.12.0->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.7.4.3)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.12.1)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.40.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.12)
# Requirement already satisfied: h5py~=3.1.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.1.0)
# Requirement already satisfied: tensorflow-estimator~=2.6 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.6.0)
# Requirement already satisfied: wheel~=0.35 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.37.0)
# Requirement already satisfied: clang~=5.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorflow>=1.9.0->deepface) (5.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.2)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.17.3)
# Requirement already satisfied: absl-py~=0.10 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.13.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: tensorboard~=2.6 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.6.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.0)
# Requirement already satisfied: gast==0.4.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: cached-property in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from h5py~=3.1.0->tensorflow>=1.9.0->deepface) (1.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorboard~=2.6->tensorflow>=1.9.0->deepface) (0.6.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorboard~=2.6->tensorflow>=1.9.0->deepface) (1.35.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorboard~=2.6->tensorflow>=1.9.0->deepface) (58.0.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorboard~=2.6->tensorflow>=1.9.0->deepface) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorboard~=2.6->tensorflow>=1.9.0->deepface) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from tensorboard~=2.6->tensorflow>=1.9.0->deepface) (1.8.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow>=1.9.0->deepface) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow>=1.9.0->deepface) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow>=1.9.0->deepface) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=1.9.0->deepface) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=1.9.0->deepface) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\jerryold\anaconda3\envs\faceemotion\lib\site-packages (from importlib-metadata->click>=7.1.2->Flask>=1.1.2->deepface) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from deepface import DeepFace

# %%
img=cv2.imread('happyboy.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img) #BGR

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
prediction=DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.33it/s]

# %%
prediction
# Out:
# {'emotion': {'angry': 6.492869647289163e-13,
#   'disgust': 1.7294703879486067e-17,
#   'fear': 3.4198891548514743e-10,
#   'happy': 100.0,
#   'sad': 1.5913298781998486e-11,
#   'surprise': 7.768921817712451e-12,
#   'neutral': 8.030255349567028e-08},
#  'dominant_emotion': 'happy',
#  'region': {'x': 53, 'y': 49, 'w': 111, 'h': 111},
#  'age': 20,
#  'gender': 'Man',
#  'race': {'asian': 0.0034676555515034124,
#   'indian': 0.22886900696903467,
#   'black': 0.0010421545994176995,
#   'white': 53.37783694267273,
#   'middle eastern': 38.44672739505768,
#   'latino hispanic': 7.9420581459999084},
#  'dominant_race': 'white'}

# %%
type(prediction)
prediction['dominant_emotion']
# Out:
# 'happy'

# %% [markdown]
# ### we are trying to draw a rectangle across the face

# %%
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    #print(faceCascade.empty())
faces=faceCascade.detectMultiScale(gray,1.1,4)

    #Draw the rectangle around the faces
for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font=cv2.FONT_HERSHEY_SIMPLEX

    #Use outText() method for
    #inserting text on video
cv2.putText(img,
               prediction['dominant_emotion'],
              (50,50),
              font,1,
              (0,0,255),
              2,
              cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
img2=cv2.imread('fearman.jpg')
plt.imshow(cv2.cvtColor(img2,cv2.COLOR_BGR2RGB))

# %%
prediction2=DeepFace.analyze(img2)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  3.79it/s]

# %%
prediction2
# Out:
# {'emotion': {'angry': 0.13959791644873717,
#   'disgust': 2.239124041971748e-06,
#   'fear': 1.483416086936956,
#   'happy': 4.9901476150210455e-05,
#   'sad': 0.349432413804973,
#   'surprise': 97.5700496178895,
#   'neutral': 0.4574527305336434},
#  'dominant_emotion': 'surprise',
#  'region': {'x': 307, 'y': 58, 'w': 186, 'h': 186},
#  'age': 27,
#  'gender': 'Man',
#  'race': {'asian': 0.0029719285521423444,
#   'indian': 0.6270700134336948,
#   'black': 99.34471249580383,
#   'white': 3.2526952509215334e-05,
#   'middle eastern': 6.749301206809832e-06,
#   'latino hispanic': 0.02521051501389593},
#  'dominant_race': 'black'}
