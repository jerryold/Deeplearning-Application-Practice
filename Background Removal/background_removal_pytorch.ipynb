# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from IPython import display
import pywintypes
import win32api

# %% [markdown]
# # 去背神器 (pytorch)

# %% [markdown]
# 支援python 版本: 3.5以上
# 支援pytorch版本 : 1.4以上

# %% [markdown]
# 對於攝影師或者是專業美工來說，去背可以說是日常進行的家常便飯，但是也正因為這個作業太頻繁也太瑣碎，所以正好成為人工智能來幫我們解決問題的好題材，除了照片修圖摳圖之外，像是直播實時更換背景，或者是可以避開人身體的彈幕，這些應用都需要將人體給分割出來。本實作將會利用谷歌的deeplab v3+來介紹如何開發去背模型。所謂的去除背景，其實目標是在預測一個逐像素的二元遮罩(binary mask)，其中，0表示是人體以外的部分，1表示是人體，在這邊服裝以及髮型也被認為是人體的一部分，髮絲級的人體分割還會涉及到matting的技術，就暫時不再本實作中討論

# %%
import glob
import os
import cv2
os.environ['TRIDENT_BACKEND'] = 'pytorch'

# !pip install tridentx --upgrade
import trident as T
from trident import *
from trident.models import efficientnet,deeplab
# Out:
# Requirement already satisfied: tridentx in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (0.7.3.19)
# Requirement already satisfied: matplotlib>=3.0.2 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tridentx) (3.4.2)
# Requirement already satisfied: scikit-image>=0.15 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tridentx) (0.18.2)
# Requirement already satisfied: pyyaml in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tridentx) (5.4.1)
# Requirement already satisfied: opencv-python in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tridentx) (4.5.3.56)
# Requirement already satisfied: setuptools in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tridentx) (52.0.0.post20210125)
# Requirement already satisfied: pillow>=4.1.1 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tridentx) (8.3.1)
# Requirement already satisfied: tensorboard>=1.15 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tridentx) (2.6.0)
# Requirement already satisfied: tqdm in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tridentx) (4.62.1)
# Requirement already satisfied: h5py in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tridentx) (3.3.0)
# Requirement already satisfied: requests in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tridentx) (2.26.0)
# Requirement already satisfied: six>=1.13.0 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tridentx) (1.16.0)
# Requirement already satisfied: scipy>=1.2 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tridentx) (1.6.2)
# Requirement already satisfied: numpy>=1.18 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tridentx) (1.20.3)
# Requirement already satisfied: dill>=0.3.1 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tridentx) (0.3.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from matplotlib>=3.0.2->tridentx) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from matplotlib>=3.0.2->tridentx) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from matplotlib>=3.0.2->tridentx) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from matplotlib>=3.0.2->tridentx) (1.3.1)
# Requirement already satisfied: networkx>=2.0 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from scikit-image>=0.15->tridentx) (2.6.2)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from scikit-image>=0.15->tridentx) (2021.8.8)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from scikit-image>=0.15->tridentx) (1.1.1)
# Requirement already satisfied: imageio>=2.3.0 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from scikit-image>=0.15->tridentx) (2.9.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tensorboard>=1.15->tridentx) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tensorboard>=1.15->tridentx) (2.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tensorboard>=1.15->tridentx) (0.4.5)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tensorboard>=1.15->tridentx) (1.8.0)
# Requirement already satisfied: protobuf>=3.6.0 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tensorboard>=1.15->tridentx) (3.17.3)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tensorboard>=1.15->tridentx) (1.39.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tensorboard>=1.15->tridentx) (1.35.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tensorboard>=1.15->tridentx) (0.13.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tensorboard>=1.15->tridentx) (0.37.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tensorboard>=1.15->tridentx) (3.3.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard>=1.15->tridentx) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard>=1.15->tridentx) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard>=1.15->tridentx) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=1.15->tridentx) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard>=1.15->tridentx) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from requests->tridentx) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from requests->tridentx) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from requests->tridentx) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from requests->tridentx) (2021.5.30)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=1.15->tridentx) (3.1.1)
# Requirement already satisfied: colorama in c:\users\jerryold\anaconda3\envs\training\lib\site-packages (from tqdm->tridentx) (0.4.4)
# trident 0.7.3.19
# Using Pytorch backend.
# Image Data Format: channels_first.
# Image Channel Order: rgb.
# Pytorch version:1.9.0.
# Automatic Mixed Precision Support:True.
# Opencv version:4.5.3.
# Pillow version:8.3.1.

# %% [markdown]
# 本次使用的數據集是吳恩達創辦的supervisely所發布的人體分割數據集Supervisely Person，在我開發的trident api中可以透過關鍵字"people"下載，裡面附的是將原圖稍作縮小的精簡版，已經足以用來訓練本次模型。若是各位對於原始數據感興趣，您也可以到 https://supervise.ly/ 即可下載取得圖資。

# %% [markdown]
# <img src="../images/supervise.png">

# %%
data_provider=load_examples_data('people')
data_provider.paired_transform_funcs=[RandomCenterCrop((224, 224),scale=(0.7,3.0))]
data_provider.image_transform_funcs=[
                     AddNoise(0.01),
                     RandomAdjustGamma(gamma_range=(0.6,1.5)),
                     RandomAdjustContrast(value_range=(0.6, 1.5)),
                     RandomAdjustHue(value_range=(-0.5, 0.5)),
                     Normalize(0,255),
                     Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])]
# Out:
# archive file is already existing, donnot need download again.
# extraction is finished, donnot need extract again.
# get people images :5711

# %% [markdown]
# 這是一組高解析度的人體分割數據集，裡面覆蓋的場景蠻完整的，包括了正面、遠景、化妝、局部身體...都包括其中，我認為唯一的缺點就是圖片選擇有點太過唯美，因此容易過擬合，在一般照片中會效果變差，但是這可以透過數據增強技術來克服。或者是建議可以將Pascal VOC或者是之前實作範例「街景分割」的數據中的「人」的部分提取出來混合，可以讓效果變得更好

# %% [markdown]
# <img src="../images/SuperviselyPerson.jpg">

# %%
data_provider.preview_images()
# Out:
# image
# <PIL.Image.Image image mode=RGB size=1792x224 at 0x243B136BD60>

# %% [markdown]
# 原本deeplab論文中使用的是resnet以及mobilenet作為主骨幹，但是既然我們已經學到了更厲害的主骨幹EfficientNet(各位可以參考實作「鑑黃大師」)，權重數更少、執行更快且準確率越高，根本就是一次滿足三種願望，所以我們採用EfficientNetB0作為主骨幹。各位可以使用summary()來檢視他的模型結構。

# %%
backbond_net=efficientnet.EfficientNetB0(pretrained=True)
backbond_net.summary()
# Out:
# model file is already existing, donnot need download again.
# 5288548 parameters have set untrainable
# 1281000 parameters have set trainable
# --------------------------------------------------------------------------------------------------------------------------------
#                  Layer (type)                   Output Shape               Weight                           Bias      Param #   FLOPS #
# ==============================================================================
# stem.conv  [Conv2d]                             [None, 32, 112, 112]       'weight', [32, 3, 3, 3]                    864  21,663,488
# stem.norm  [BatchNorm]                          [None, 32, 112, 112]       'weight', [32]                   'bias', [32]  64  1,580,544
# stem.activation  [Swish]                        [None, 32, 112, 112]                                                  0  0
# stem  [Conv2d_Block]                            [None, 32, 112, 112]                                                  0  0
# block1a.0.conv  [DepthwiseConv2d]               [None, 32, 112, 112]       'weight', [32, 1, 3, 3]                    288  7,212,800
# block1a.0.norm  [BatchNorm]                     [None, 32, 112, 112]       'weight', [32]                   'bias', [32]  64  1,580,544
# block1a.0.activation  [Swish]                   [None, 32, 112, 112]                                                  0  0
# block1a.0  [DepthwiseConv2d_Block]              [None, 32, 112, 112]                                                  0  0
# block1a.1.pool  [GlobalAvgPool2d]               [None, 32]                                                            0  0
# block1a.1.squeeze  [Conv2d]                     [None, 8, 1, 1]            'weight', [8, 32, 1, 1]          'bias', [8]  264  526
# block1a.1.excite  [Conv2d]                      [None, 32, 1, 1]           'weight', [32, 8, 1, 1]          'bias', [32]  288  574
# block1a.1  [SqueezeExcite]                      [None, 32, 112, 112]                                                  0  0
# block1a.2.conv  [Conv2d]                        [None, 16, 112, 112]       'weight', [16, 32, 1, 1]                   512  12,832,512
# block1a.2.norm  [BatchNorm]                     [None, 16, 112, 112]       'weight', [16]                   'bias', [16]  32  777,728
# block1a.2  [Conv2d_Block]                       [None, 16, 112, 112]                                                  0  0
# block1a.3  [Identity]                           [None, 16, 112, 112]                                                  0  0
# block2a.0.conv  [Conv2d]                        [None, 96, 112, 112]       'weight', [96, 16, 1, 1]                   1,536  38,522,624
# block2a.0.norm  [BatchNorm]                     [None, 96, 112, 112]       'weight', [96]                   'bias', [96]  192  4,791,808
# block2a.0.activation  [Swish]                   [None, 96, 112, 112]                                                  0  0
# block2a.0  [Conv2d_Block]                       [None, 96, 112, 112]                                                  0  0
# block2a.1.conv  [DepthwiseConv2d]               [None, 96, 56, 56]         'weight', [96, 1, 3, 3]                    864  5,415,872
# block2a.1.norm  [BatchNorm]                     [None, 96, 56, 56]         'weight', [96]                   'bias', [96]  192  1,197,952
# block2a.1.activation  [Swish]                   [None, 96, 56, 56]                                                    0  0
# block2a.1  [DepthwiseConv2d_Block]              [None, 96, 56, 56]                                                    0  0
# block2a.2.pool  [GlobalAvgPool2d]               [None, 96]                                                            0  0
# block2a.2.squeeze  [Conv2d]                     [None, 4, 1, 1]            'weight', [4, 96, 1, 1]          'bias', [4]  388  774
# block2a.2.excite  [Conv2d]                      [None, 96, 1, 1]           'weight', [96, 4, 1, 1]          'bias', [96]  480  958
# block2a.2  [SqueezeExcite]                      [None, 96, 56, 56]                                                    0  0
# block2a.3.conv  [Conv2d]                        [None, 24, 56, 56]         'weight', [24, 96, 1, 1]                   2,304  14,447,552
# block2a.3.norm  [BatchNorm]                     [None, 24, 56, 56]         'weight', [24]                   'bias', [24]  48  294,784
# block2a.3  [Conv2d_Block]                       [None, 24, 56, 56]                                                    0  0
# block2a.4  [Identity]                           [None, 24, 56, 56]                                                    0  0
# block2b.Identity  [Identity]                    [None, 24, 56, 56]                                                    0  0
# block2b.branch2.0.conv  [Conv2d]                [None, 144, 56, 56]        'weight', [144, 24, 1, 1]                  3,456  21,672,896
# block2b.branch2.0.norm  [BatchNorm]             [None, 144, 56, 56]        'weight', [144]                  'bias', [144]  288  1,800,064
# block2b.branch2.0.activation  [Swish]           [None, 144, 56, 56]                                                   0  0
# block2b.branch2.0  [Conv2d_Block]               [None, 144, 56, 56]                                                   0  0
# block2b.branch2.1.conv  [DepthwiseConv2d]       [None, 144, 56, 56]        'weight', [144, 1, 3, 3]                   1,296  8,125,376
# block2b.branch2.1.norm  [BatchNorm]             [None, 144, 56, 56]        'weight', [144]                  'bias', [144]  288  1,800,064
# block2b.branch2.1.activation  [Swish]           [None, 144, 56, 56]                                                   0  0
# block2b.branch2.1  [DepthwiseConv2d_Block]      [None, 144, 56, 56]                                                   0  0
# block2b.branch2.2.pool  [GlobalAvgPool2d]       [None, 144]                                                           0  0
# block2b.branch2.2.squeeze  [Conv2d]             [None, 6, 1, 1]            'weight', [6, 144, 1, 1]         'bias', [6]  870  1,738
# block2b.branch2.2.excite  [Conv2d]              [None, 144, 1, 1]          'weight', [144, 6, 1, 1]         'bias', [144]  1,008  2,014
# block2b.branch2.2  [SqueezeExcite]              [None, 144, 56, 56]                                                   0  0
# block2b.branch2.3.conv  [Conv2d]                [None, 24, 56, 56]         'weight', [24, 144, 1, 1]                  3,456  21,672,896
# block2b.branch2.3.norm  [BatchNorm]             [None, 24, 56, 56]         'weight', [24]                   'bias', [24]  48  294,784
# block2b.branch2.3  [Conv2d_Block]               [None, 24, 56, 56]                                                    0  0
# block2b.branch2.4  [Dropout]                    [None, 24, 56, 56]                                                    0  0
# block2b  [ShortCut2d]                           [None, 24, 56, 56]                                                    0  0
# block3a.0.conv  [Conv2d]                        [None, 144, 56, 56]        'weight', [144, 24, 1, 1]                  3,456  21,672,896
# block3a.0.norm  [BatchNorm]                     [None, 144, 56, 56]        'weight', [144]                  'bias', [144]  288  1,800,064
# block3a.0.activation  [Swish]                   [None, 144, 56, 56]                                                   0  0
# block3a.0  [Conv2d_Block]                       [None, 144, 56, 56]                                                   0  0
# block3a.1.conv  [DepthwiseConv2d]               [None, 144, 28, 28]        'weight', [144, 1, 5, 5]                   3,600  5,644,016
# block3a.1.norm  [BatchNorm]                     [None, 144, 28, 28]        'weight', [144]                  'bias', [144]  288  450,016
# block3a.1.activation  [Swish]                   [None, 144, 28, 28]                                                   0  0
# block3a.1  [DepthwiseConv2d_Block]              [None, 144, 28, 28]                                                   0  0
# block3a.2.pool  [GlobalAvgPool2d]               [None, 144]                                                           0  0
# block3a.2.squeeze  [Conv2d]                     [None, 6, 1, 1]            'weight', [6, 144, 1, 1]         'bias', [6]  870  1,738
# block3a.2.excite  [Conv2d]                      [None, 144, 1, 1]          'weight', [144, 6, 1, 1]         'bias', [144]  1,008  2,014
# block3a.2  [SqueezeExcite]                      [None, 144, 28, 28]                                                   0  0
# block3a.3.conv  [Conv2d]                        [None, 40, 28, 28]         'weight', [40, 144, 1, 1]                  5,760  9,030,896
# block3a.3.norm  [BatchNorm]                     [None, 40, 28, 28]         'weight', [40]                   'bias', [40]  80  123,872
# block3a.3  [Conv2d_Block]                       [None, 40, 28, 28]                                                    0  0
# block3a.4  [Identity]                           [None, 40, 28, 28]                                                    0  0
# block3b.Identity  [Identity]                    [None, 40, 28, 28]                                                    0  0
# block3b.branch2.0.conv  [Conv2d]                [None, 240, 28, 28]        'weight', [240, 40, 1, 1]                  9,600  15,052,016
# block3b.branch2.0.norm  [BatchNorm]             [None, 240, 28, 28]        'weight', [240]                  'bias', [240]  480  751,072
# block3b.branch2.0.activation  [Swish]           [None, 240, 28, 28]                                                   0  0
# block3b.branch2.0  [Conv2d_Block]               [None, 240, 28, 28]                                                   0  0
# block3b.branch2.1.conv  [DepthwiseConv2d]       [None, 240, 28, 28]        'weight', [240, 1, 5, 5]                   6,000  9,407,216
# block3b.branch2.1.norm  [BatchNorm]             [None, 240, 28, 28]        'weight', [240]                  'bias', [240]  480  751,072
# block3b.branch2.1.activation  [Swish]           [None, 240, 28, 28]                                                   0  0
# block3b.branch2.1  [DepthwiseConv2d_Block]      [None, 240, 28, 28]                                                   0  0
# block3b.branch2.2.pool  [GlobalAvgPool2d]       [None, 240]                                                           0  0
# block3b.branch2.2.squeeze  [Conv2d]             [None, 10, 1, 1]           'weight', [10, 240, 1, 1]        'bias', [10]  2,410  4,818
# block3b.branch2.2.excite  [Conv2d]              [None, 240, 1, 1]          'weight', [240, 10, 1, 1]        'bias', [240]  2,640  5,278
# block3b.branch2.2  [SqueezeExcite]              [None, 240, 28, 28]                                                   0  0
# block3b.branch2.3.conv  [Conv2d]                [None, 40, 28, 28]         'weight', [40, 240, 1, 1]                  9,600  15,052,016
# block3b.branch2.3.norm  [BatchNorm]             [None, 40, 28, 28]         'weight', [40]                   'bias', [40]  80  123,872
# block3b.branch2.3  [Conv2d_Block]               [None, 40, 28, 28]                                                    0  0
# block3b.branch2.4  [Dropout]                    [None, 40, 28, 28]                                                    0  0
# block3b  [ShortCut2d]                           [None, 40, 28, 28]                                                    0  0
# block4a.0.conv  [Conv2d]                        [None, 240, 28, 28]        'weight', [240, 40, 1, 1]                  9,600  15,052,016
# block4a.0.norm  [BatchNorm]                     [None, 240, 28, 28]        'weight', [240]                  'bias', [240]  480  751,072
# block4a.0.activation  [Swish]                   [None, 240, 28, 28]                                                   0  0
# block4a.0  [Conv2d_Block]                       [None, 240, 28, 28]                                                   0  0
# block4a.1.conv  [DepthwiseConv2d]               [None, 240, 14, 14]        'weight', [240, 1, 3, 3]                   2,160  846,524
# block4a.1.norm  [BatchNorm]                     [None, 240, 14, 14]        'weight', [240]                  'bias', [240]  480  187,768
# block4a.1.activation  [Swish]                   [None, 240, 14, 14]                                                   0  0
# block4a.1  [DepthwiseConv2d_Block]              [None, 240, 14, 14]                                                   0  0
# block4a.2.pool  [GlobalAvgPool2d]               [None, 240]                                                           0  0
# block4a.2.squeeze  [Conv2d]                     [None, 10, 1, 1]           'weight', [10, 240, 1, 1]        'bias', [10]  2,410  4,818
# block4a.2.excite  [Conv2d]                      [None, 240, 1, 1]          'weight', [240, 10, 1, 1]        'bias', [240]  2,640  5,278
# block4a.2  [SqueezeExcite]                      [None, 240, 14, 14]                                                   0  0
# block4a.3.conv  [Conv2d]                        [None, 80, 14, 14]         'weight', [80, 240, 1, 1]                  19,200  7,526,204
# block4a.3.norm  [BatchNorm]                     [None, 80, 14, 14]         'weight', [80]                   'bias', [80]  160  62,328
# block4a.3  [Conv2d_Block]                       [None, 80, 14, 14]                                                    0  0
# block4a.4  [Identity]                           [None, 80, 14, 14]                                                    0  0
# block4b.Identity  [Identity]                    [None, 80, 14, 14]                                                    0  0
# block4b.branch2.0.conv  [Conv2d]                [None, 480, 14, 14]        'weight', [480, 80, 1, 1]                  38,400  15,052,604
# block4b.branch2.0.norm  [BatchNorm]             [None, 480, 14, 14]        'weight', [480]                  'bias', [480]  960  375,928
# block4b.branch2.0.activation  [Swish]           [None, 480, 14, 14]                                                   0  0
# block4b.branch2.0  [Conv2d_Block]               [None, 480, 14, 14]                                                   0  0
# block4b.branch2.1.conv  [DepthwiseConv2d]       [None, 480, 14, 14]        'weight', [480, 1, 3, 3]                   4,320  1,693,244
# block4b.branch2.1.norm  [BatchNorm]             [None, 480, 14, 14]        'weight', [480]                  'bias', [480]  960  375,928
# block4b.branch2.1.activation  [Swish]           [None, 480, 14, 14]                                                   0  0
# block4b.branch2.1  [DepthwiseConv2d_Block]      [None, 480, 14, 14]                                                   0  0
# block4b.branch2.2.pool  [GlobalAvgPool2d]       [None, 480]                                                           0  0
# block4b.branch2.2.squeeze  [Conv2d]             [None, 20, 1, 1]           'weight', [20, 480, 1, 1]        'bias', [20]  9,620  19,238
# block4b.branch2.2.excite  [Conv2d]              [None, 480, 1, 1]          'weight', [480, 20, 1, 1]        'bias', [480]  10,080  20,158
# block4b.branch2.2  [SqueezeExcite]              [None, 480, 14, 14]                                                   0  0
# block4b.branch2.3.conv  [Conv2d]                [None, 80, 14, 14]         'weight', [80, 480, 1, 1]                  38,400  15,052,604
# block4b.branch2.3.norm  [BatchNorm]             [None, 80, 14, 14]         'weight', [80]                   'bias', [80]  160  62,328
# block4b.branch2.3  [Conv2d_Block]               [None, 80, 14, 14]                                                    0  0
# block4b.branch2.4  [Dropout]                    [None, 80, 14, 14]                                                    0  0
# block4b  [ShortCut2d]                           [None, 80, 14, 14]                                                    0  0
# block4c.Identity  [Identity]                    [None, 80, 14, 14]                                                    0  0
# block4c.branch2.0.conv  [Conv2d]                [None, 480, 14, 14]        'weight', [480, 80, 1, 1]                  38,400  15,052,604
# block4c.branch2.0.norm  [BatchNorm]             [None, 480, 14, 14]        'weight', [480]                  'bias', [480]  960  375,928
# block4c.branch2.0.activation  [Swish]           [None, 480, 14, 14]                                                   0  0
# block4c.branch2.0  [Conv2d_Block]               [None, 480, 14, 14]                                                   0  0
# block4c.branch2.1.conv  [DepthwiseConv2d]       [None, 480, 14, 14]        'weight', [480, 1, 3, 3]                   4,320  1,693,244
# block4c.branch2.1.norm  [BatchNorm]             [None, 480, 14, 14]        'weight', [480]                  'bias', [480]  960  375,928
# block4c.branch2.1.activation  [Swish]           [None, 480, 14, 14]                                                   0  0
# block4c.branch2.1  [DepthwiseConv2d_Block]      [None, 480, 14, 14]                                                   0  0
# block4c.branch2.2.pool  [GlobalAvgPool2d]       [None, 480]                                                           0  0
# block4c.branch2.2.squeeze  [Conv2d]             [None, 20, 1, 1]           'weight', [20, 480, 1, 1]        'bias', [20]  9,620  19,238
# block4c.branch2.2.excite  [Conv2d]              [None, 480, 1, 1]          'weight', [480, 20, 1, 1]        'bias', [480]  10,080  20,158
# block4c.branch2.2  [SqueezeExcite]              [None, 480, 14, 14]                                                   0  0
# block4c.branch2.3.conv  [Conv2d]                [None, 80, 14, 14]         'weight', [80, 480, 1, 1]                  38,400  15,052,604
# block4c.branch2.3.norm  [BatchNorm]             [None, 80, 14, 14]         'weight', [80]                   'bias', [80]  160  62,328
# block4c.branch2.3  [Conv2d_Block]               [None, 80, 14, 14]                                                    0  0
# block4c.branch2.4  [Dropout]                    [None, 80, 14, 14]                                                    0  0
# block4c  [ShortCut2d]                           [None, 80, 14, 14]                                                    0  0
# block5a.0.conv  [Conv2d]                        [None, 480, 14, 14]        'weight', [480, 80, 1, 1]                  38,400  15,052,604
# block5a.0.norm  [BatchNorm]                     [None, 480, 14, 14]        'weight', [480]                  'bias', [480]  960  375,928
# block5a.0.activation  [Swish]                   [None, 480, 14, 14]                                                   0  0
# block5a.0  [Conv2d_Block]                       [None, 480, 14, 14]                                                   0  0
# block5a.1.conv  [DepthwiseConv2d]               [None, 480, 14, 14]        'weight', [480, 1, 5, 5]                   12,000  4,703,804
# block5a.1.norm  [BatchNorm]                     [None, 480, 14, 14]        'weight', [480]                  'bias', [480]  960  375,928
# block5a.1.activation  [Swish]                   [None, 480, 14, 14]                                                   0  0
# block5a.1  [DepthwiseConv2d_Block]              [None, 480, 14, 14]                                                   0  0
# block5a.2.pool  [GlobalAvgPool2d]               [None, 480]                                                           0  0
# block5a.2.squeeze  [Conv2d]                     [None, 20, 1, 1]           'weight', [20, 480, 1, 1]        'bias', [20]  9,620  19,238
# block5a.2.excite  [Conv2d]                      [None, 480, 1, 1]          'weight', [480, 20, 1, 1]        'bias', [480]  10,080  20,158
# block5a.2  [SqueezeExcite]                      [None, 480, 14, 14]                                                   0  0
# block5a.3.conv  [Conv2d]                        [None, 112, 14, 14]        'weight', [112, 480, 1, 1]                 53,760  21,073,724
# block5a.3.norm  [BatchNorm]                     [None, 112, 14, 14]        'weight', [112]                  'bias', [112]  224  87,416
# block5a.3  [Conv2d_Block]                       [None, 112, 14, 14]                                                   0  0
# block5a.4  [Identity]                           [None, 112, 14, 14]                                                   0  0
# block5b.Identity  [Identity]                    [None, 112, 14, 14]                                                   0  0
# block5b.branch2.0.conv  [Conv2d]                [None, 672, 14, 14]        'weight', [672, 112, 1, 1]                 75,264  29,503,292
# block5b.branch2.0.norm  [BatchNorm]             [None, 672, 14, 14]        'weight', [672]                  'bias', [672]  1,344  526,456
# block5b.branch2.0.activation  [Swish]           [None, 672, 14, 14]                                                   0  0
# block5b.branch2.0  [Conv2d_Block]               [None, 672, 14, 14]                                                   0  0
# block5b.branch2.1.conv  [DepthwiseConv2d]       [None, 672, 14, 14]        'weight', [672, 1, 5, 5]                   16,800  6,585,404
# block5b.branch2.1.norm  [BatchNorm]             [None, 672, 14, 14]        'weight', [672]                  'bias', [672]  1,344  526,456
# block5b.branch2.1.activation  [Swish]           [None, 672, 14, 14]                                                   0  0
# block5b.branch2.1  [DepthwiseConv2d_Block]      [None, 672, 14, 14]                                                   0  0
# block5b.branch2.2.pool  [GlobalAvgPool2d]       [None, 672]                                                           0  0
# block5b.branch2.2.squeeze  [Conv2d]             [None, 28, 1, 1]           'weight', [28, 672, 1, 1]        'bias', [28]  18,844  37,686
# block5b.branch2.2.excite  [Conv2d]              [None, 672, 1, 1]          'weight', [672, 28, 1, 1]        'bias', [672]  19,488  38,974
# block5b.branch2.2  [SqueezeExcite]              [None, 672, 14, 14]                                                   0  0
# block5b.branch2.3.conv  [Conv2d]                [None, 112, 14, 14]        'weight', [112, 672, 1, 1]                 75,264  29,503,292
# block5b.branch2.3.norm  [BatchNorm]             [None, 112, 14, 14]        'weight', [112]                  'bias', [112]  224  87,416
# block5b.branch2.3  [Conv2d_Block]               [None, 112, 14, 14]                                                   0  0
# block5b.branch2.4  [Dropout]                    [None, 112, 14, 14]                                                   0  0
# block5b  [ShortCut2d]                           [None, 112, 14, 14]                                                   0  0
# block5c.Identity  [Identity]                    [None, 112, 14, 14]                                                   0  0
# block5c.branch2.0.conv  [Conv2d]                [None, 672, 14, 14]        'weight', [672, 112, 1, 1]                 75,264  29,503,292
# block5c.branch2.0.norm  [BatchNorm]             [None, 672, 14, 14]        'weight', [672]                  'bias', [672]  1,344  526,456
# block5c.branch2.0.activation  [Swish]           [None, 672, 14, 14]                                                   0  0
# block5c.branch2.0  [Conv2d_Block]               [None, 672, 14, 14]                                                   0  0
# block5c.branch2.1.conv  [DepthwiseConv2d]       [None, 672, 14, 14]        'weight', [672, 1, 5, 5]                   16,800  6,585,404
# block5c.branch2.1.norm  [BatchNorm]             [None, 672, 14, 14]        'weight', [672]                  'bias', [672]  1,344  526,456
# block5c.branch2.1.activation  [Swish]           [None, 672, 14, 14]                                                   0  0
# block5c.branch2.1  [DepthwiseConv2d_Block]      [None, 672, 14, 14]                                                   0  0
# block5c.branch2.2.pool  [GlobalAvgPool2d]       [None, 672]                                                           0  0
# block5c.branch2.2.squeeze  [Conv2d]             [None, 28, 1, 1]           'weight', [28, 672, 1, 1]        'bias', [28]  18,844  37,686
# block5c.branch2.2.excite  [Conv2d]              [None, 672, 1, 1]          'weight', [672, 28, 1, 1]        'bias', [672]  19,488  38,974
# block5c.branch2.2  [SqueezeExcite]              [None, 672, 14, 14]                                                   0  0
# block5c.branch2.3.conv  [Conv2d]                [None, 112, 14, 14]        'weight', [112, 672, 1, 1]                 75,264  29,503,292
# block5c.branch2.3.norm  [BatchNorm]             [None, 112, 14, 14]        'weight', [112]                  'bias', [112]  224  87,416
# block5c.branch2.3  [Conv2d_Block]               [None, 112, 14, 14]                                                   0  0
# block5c.branch2.4  [Dropout]                    [None, 112, 14, 14]                                                   0  0
# block5c  [ShortCut2d]                           [None, 112, 14, 14]                                                   0  0
# block6a.0.conv  [Conv2d]                        [None, 672, 14, 14]        'weight', [672, 112, 1, 1]                 75,264  29,503,292
# block6a.0.norm  [BatchNorm]                     [None, 672, 14, 14]        'weight', [672]                  'bias', [672]  1,344  526,456
# block6a.0.activation  [Swish]                   [None, 672, 14, 14]                                                   0  0
# block6a.0  [Conv2d_Block]                       [None, 672, 14, 14]                                                   0  0
# block6a.1.conv  [DepthwiseConv2d]               [None, 672, 7, 7]          'weight', [672, 1, 5, 5]                   16,800  1,646,351
# block6a.1.norm  [BatchNorm]                     [None, 672, 7, 7]          'weight', [672]                  'bias', [672]  1,344  131,614
# block6a.1.activation  [Swish]                   [None, 672, 7, 7]                                                     0  0
# block6a.1  [DepthwiseConv2d_Block]              [None, 672, 7, 7]                                                     0  0
# block6a.2.pool  [GlobalAvgPool2d]               [None, 672]                                                           0  0
# block6a.2.squeeze  [Conv2d]                     [None, 28, 1, 1]           'weight', [28, 672, 1, 1]        'bias', [28]  18,844  37,686
# block6a.2.excite  [Conv2d]                      [None, 672, 1, 1]          'weight', [672, 28, 1, 1]        'bias', [672]  19,488  38,974
# block6a.2  [SqueezeExcite]                      [None, 672, 7, 7]                                                     0  0
# block6a.3.conv  [Conv2d]                        [None, 192, 7, 7]          'weight', [192, 672, 1, 1]                 129,024  12,644,303
# block6a.3.norm  [BatchNorm]                     [None, 192, 7, 7]          'weight', [192]                  'bias', [192]  384  37,534
# block6a.3  [Conv2d_Block]                       [None, 192, 7, 7]                                                     0  0
# block6a.4  [Identity]                           [None, 192, 7, 7]                                                     0  0
# block6b.Identity  [Identity]                    [None, 192, 7, 7]                                                     0  0
# block6b.branch2.0.conv  [Conv2d]                [None, 1152, 7, 7]         'weight', [1152, 192, 1, 1]                221,184  21,675,983
# block6b.branch2.0.norm  [BatchNorm]             [None, 1152, 7, 7]         'weight', [1152]                 'bias', [1152]  2,304  225,694
# block6b.branch2.0.activation  [Swish]           [None, 1152, 7, 7]                                                    0  0
# block6b.branch2.0  [Conv2d_Block]               [None, 1152, 7, 7]                                                    0  0
# block6b.branch2.1.conv  [DepthwiseConv2d]       [None, 1152, 7, 7]         'weight', [1152, 1, 5, 5]                  28,800  2,822,351
# block6b.branch2.1.norm  [BatchNorm]             [None, 1152, 7, 7]         'weight', [1152]                 'bias', [1152]  2,304  225,694
# block6b.branch2.1.activation  [Swish]           [None, 1152, 7, 7]                                                    0  0
# block6b.branch2.1  [DepthwiseConv2d_Block]      [None, 1152, 7, 7]                                                    0  0
# block6b.branch2.2.pool  [GlobalAvgPool2d]       [None, 1152]                                                          0  0
# block6b.branch2.2.squeeze  [Conv2d]             [None, 48, 1, 1]           'weight', [48, 1152, 1, 1]       'bias', [48]  55,344  110,686
# block6b.branch2.2.excite  [Conv2d]              [None, 1152, 1, 1]         'weight', [1152, 48, 1, 1]       'bias', [1152]  56,448  112,894
# block6b.branch2.2  [SqueezeExcite]              [None, 1152, 7, 7]                                                    0  0
# block6b.branch2.3.conv  [Conv2d]                [None, 192, 7, 7]          'weight', [192, 1152, 1, 1]                221,184  21,675,983
# block6b.branch2.3.norm  [BatchNorm]             [None, 192, 7, 7]          'weight', [192]                  'bias', [192]  384  37,534
# block6b.branch2.3  [Conv2d_Block]               [None, 192, 7, 7]                                                     0  0
# block6b.branch2.4  [Dropout]                    [None, 192, 7, 7]                                                     0  0
# block6b  [ShortCut2d]                           [None, 192, 7, 7]                                                     0  0
# block6c.Identity  [Identity]                    [None, 192, 7, 7]                                                     0  0
# block6c.branch2.0.conv  [Conv2d]                [None, 1152, 7, 7]         'weight', [1152, 192, 1, 1]                221,184  21,675,983
# block6c.branch2.0.norm  [BatchNorm]             [None, 1152, 7, 7]         'weight', [1152]                 'bias', [1152]  2,304  225,694
# block6c.branch2.0.activation  [Swish]           [None, 1152, 7, 7]                                                    0  0
# block6c.branch2.0  [Conv2d_Block]               [None, 1152, 7, 7]                                                    0  0
# block6c.branch2.1.conv  [DepthwiseConv2d]       [None, 1152, 7, 7]         'weight', [1152, 1, 5, 5]                  28,800  2,822,351
# block6c.branch2.1.norm  [BatchNorm]             [None, 1152, 7, 7]         'weight', [1152]                 'bias', [1152]  2,304  225,694
# block6c.branch2.1.activation  [Swish]           [None, 1152, 7, 7]                                                    0  0
# block6c.branch2.1  [DepthwiseConv2d_Block]      [None, 1152, 7, 7]                                                    0  0
# block6c.branch2.2.pool  [GlobalAvgPool2d]       [None, 1152]                                                          0  0
# block6c.branch2.2.squeeze  [Conv2d]             [None, 48, 1, 1]           'weight', [48, 1152, 1, 1]       'bias', [48]  55,344  110,686
# block6c.branch2.2.excite  [Conv2d]              [None, 1152, 1, 1]         'weight', [1152, 48, 1, 1]       'bias', [1152]  56,448  112,894
# block6c.branch2.2  [SqueezeExcite]              [None, 1152, 7, 7]                                                    0  0
# block6c.branch2.3.conv  [Conv2d]                [None, 192, 7, 7]          'weight', [192, 1152, 1, 1]                221,184  21,675,983
# block6c.branch2.3.norm  [BatchNorm]             [None, 192, 7, 7]          'weight', [192]                  'bias', [192]  384  37,534
# block6c.branch2.3  [Conv2d_Block]               [None, 192, 7, 7]                                                     0  0
# block6c.branch2.4  [Dropout]                    [None, 192, 7, 7]                                                     0  0
# block6c  [ShortCut2d]                           [None, 192, 7, 7]                                                     0  0
# block6d.Identity  [Identity]                    [None, 192, 7, 7]                                                     0  0
# block6d.branch2.0.conv  [Conv2d]                [None, 1152, 7, 7]         'weight', [1152, 192, 1, 1]                221,184  21,675,983
# block6d.branch2.0.norm  [BatchNorm]             [None, 1152, 7, 7]         'weight', [1152]                 'bias', [1152]  2,304  225,694
# block6d.branch2.0.activation  [Swish]           [None, 1152, 7, 7]                                                    0  0
# block6d.branch2.0  [Conv2d_Block]               [None, 1152, 7, 7]                                                    0  0
# block6d.branch2.1.conv  [DepthwiseConv2d]       [None, 1152, 7, 7]         'weight', [1152, 1, 5, 5]                  28,800  2,822,351
# block6d.branch2.1.norm  [BatchNorm]             [None, 1152, 7, 7]         'weight', [1152]                 'bias', [1152]  2,304  225,694
# block6d.branch2.1.activation  [Swish]           [None, 1152, 7, 7]                                                    0  0
# block6d.branch2.1  [DepthwiseConv2d_Block]      [None, 1152, 7, 7]                                                    0  0
# block6d.branch2.2.pool  [GlobalAvgPool2d]       [None, 1152]                                                          0  0
# block6d.branch2.2.squeeze  [Conv2d]             [None, 48, 1, 1]           'weight', [48, 1152, 1, 1]       'bias', [48]  55,344  110,686
# block6d.branch2.2.excite  [Conv2d]              [None, 1152, 1, 1]         'weight', [1152, 48, 1, 1]       'bias', [1152]  56,448  112,894
# block6d.branch2.2  [SqueezeExcite]              [None, 1152, 7, 7]                                                    0  0
# block6d.branch2.3.conv  [Conv2d]                [None, 192, 7, 7]          'weight', [192, 1152, 1, 1]                221,184  21,675,983
# block6d.branch2.3.norm  [BatchNorm]             [None, 192, 7, 7]          'weight', [192]                  'bias', [192]  384  37,534
# block6d.branch2.3  [Conv2d_Block]               [None, 192, 7, 7]                                                     0  0
# block6d.branch2.4  [Dropout]                    [None, 192, 7, 7]                                                     0  0
# block6d  [ShortCut2d]                           [None, 192, 7, 7]                                                     0  0
# block7a.0.conv  [Conv2d]                        [None, 1152, 7, 7]         'weight', [1152, 192, 1, 1]                221,184  21,675,983
# block7a.0.norm  [BatchNorm]                     [None, 1152, 7, 7]         'weight', [1152]                 'bias', [1152]  2,304  225,694
# block7a.0.activation  [Swish]                   [None, 1152, 7, 7]                                                    0  0
# block7a.0  [Conv2d_Block]                       [None, 1152, 7, 7]                                                    0  0
# block7a.1.conv  [DepthwiseConv2d]               [None, 1152, 7, 7]         'weight', [1152, 1, 3, 3]                  10,368  1,016,015
# block7a.1.norm  [BatchNorm]                     [None, 1152, 7, 7]         'weight', [1152]                 'bias', [1152]  2,304  225,694
# block7a.1.activation  [Swish]                   [None, 1152, 7, 7]                                                    0  0
# block7a.1  [DepthwiseConv2d_Block]              [None, 1152, 7, 7]                                                    0  0
# block7a.2.pool  [GlobalAvgPool2d]               [None, 1152]                                                          0  0
# block7a.2.squeeze  [Conv2d]                     [None, 48, 1, 1]           'weight', [48, 1152, 1, 1]       'bias', [48]  55,344  110,686
# block7a.2.excite  [Conv2d]                      [None, 1152, 1, 1]         'weight', [1152, 48, 1, 1]       'bias', [1152]  56,448  112,894
# block7a.2  [SqueezeExcite]                      [None, 1152, 7, 7]                                                    0  0
# block7a.3.conv  [Conv2d]                        [None, 320, 7, 7]          'weight', [320, 1152, 1, 1]                368,640  36,126,671
# block7a.3.norm  [BatchNorm]                     [None, 320, 7, 7]          'weight', [320]                  'bias', [320]  640  62,622
# block7a.3  [Conv2d_Block]                       [None, 320, 7, 7]                                                     0  0
# block7a.4  [Identity]                           [None, 320, 7, 7]                                                     0  0
# top_conv.conv  [Conv2d]                         [None, 1280, 7, 7]         'weight', [1280, 320, 1, 1]                409,600  40,140,751
# top_conv.norm  [BatchNorm]                      [None, 1280, 7, 7]         'weight', [1280]                 'bias', [1280]  2,560  250,782
# top_conv.activation  [Swish]                    [None, 1280, 7, 7]                                                    0  0
# top_conv  [Conv2d_Block]                        [None, 1280, 7, 7]                                                    0  0
# avg_pool  [GlobalAvgPool2d]                     [None, 1280]                                                          0  0
# top_dropout  [Dropout]                          [None, 1280]                                                          0  0
# fc  [Dense]                                     [None, 1000]               'weight', [1000, 1280]           'bias', [1000]  1,281,000  2,561,998
# softmax  [SoftMax]                              [None, 1000]                                                          0  0
# ================================================================
# Total params: 5,288,548
# Trainable params: 1,281,000
# Non-trainable params: 4,007,548
# Total MACC: 399,300,484
# Total FLOPs: 0.79837 GFLOPs
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 226.60
# Params size (MB): 20.17
# Estimated Total Size (MB): 247.34
# ----------------------------------------------------------------
# ImageClassificationModel()

# %% [markdown]
# <img src="../images/deeplabv3plus.png">

# %% [markdown]
# 在Deeplab v3+中的主骨幹範圍總共將原圖下採樣4次，等於是長寬縮小1/16倍，因此要將EfficientNet裁切成適合Deeplab v3+使用的話，需要能夠找到圖像長寬縮小1/16倍的主骨幹範圍。在trident API中，會自動搜索圖像長寬縮小1/4倍(224x224縮小到56x56)以及1/16(224x224縮小到14x14)之處，來作為低層級特徵(low-level features)以及連接ASPP的高階特徵使用。對應到生成的Deeplab結構分別為backbond1.x以及backbond2.x。為了節省計算量，最後下採樣的解碼器，我使用depthwise卷積來替代標準的卷積。

# %%
backbond=backbond_net.model
backbond.trainable=False
deeplabv3=deeplab.DeeplabV3_plus(backbond,input_shape=(3,224,224),atrous_rates=(6,12,18,24),num_filters=256,classes=2)
deeplabv3.summary()
deeplabv3.preprocess_flow=backbond_net.preprocess_flow
# Out:
# 1281000 parameters have set untrainable
# --------------------------------------------------------------------------------------------------------------------------------
#                    Layer (type)                     Output Shape               Weight                           Bias      Param #   FLOPS #
# ==============================================================================
# backbond1.0.conv  [Conv2d]                          [None, 32, 112, 112]       'weight', [32, 3, 3, 3]                    864  21,663,488
# backbond1.0.norm  [BatchNorm]                       [None, 32, 112, 112]       'weight', [32]                   'bias', [32]  64  1,580,544
# backbond1.0.activation  [Swish]                     [None, 32, 112, 112]                                                  0  0
# backbond1.0  [Conv2d_Block]                         [None, 32, 112, 112]                                                  0  0
# backbond1.1.0.conv  [DepthwiseConv2d]               [None, 32, 112, 112]       'weight', [32, 1, 3, 3]                    288  7,212,800
# backbond1.1.0.norm  [BatchNorm]                     [None, 32, 112, 112]       'weight', [32]                   'bias', [32]  64  1,580,544
# backbond1.1.0.activation  [Swish]                   [None, 32, 112, 112]                                                  0  0
# backbond1.1.0  [DepthwiseConv2d_Block]              [None, 32, 112, 112]                                                  0  0
# backbond1.1.1.pool  [GlobalAvgPool2d]               [None, 32]                                                            0  0
# backbond1.1.1.squeeze  [Conv2d]                     [None, 8, 1, 1]            'weight', [8, 32, 1, 1]          'bias', [8]  264  526
# backbond1.1.1.excite  [Conv2d]                      [None, 32, 1, 1]           'weight', [32, 8, 1, 1]          'bias', [32]  288  574
# backbond1.1.1  [SqueezeExcite]                      [None, 32, 112, 112]                                                  0  0
# backbond1.1.2.conv  [Conv2d]                        [None, 16, 112, 112]       'weight', [16, 32, 1, 1]                   512  12,832,512
# backbond1.1.2.norm  [BatchNorm]                     [None, 16, 112, 112]       'weight', [16]                   'bias', [16]  32  777,728
# backbond1.1.2  [Conv2d_Block]                       [None, 16, 112, 112]                                                  0  0
# backbond1.1.3  [Identity]                           [None, 16, 112, 112]                                                  0  0
# backbond1.2.0.conv  [Conv2d]                        [None, 96, 112, 112]       'weight', [96, 16, 1, 1]                   1,536  38,522,624
# backbond1.2.0.norm  [BatchNorm]                     [None, 96, 112, 112]       'weight', [96]                   'bias', [96]  192  4,791,808
# backbond1.2.0.activation  [Swish]                   [None, 96, 112, 112]                                                  0  0
# backbond1.2.0  [Conv2d_Block]                       [None, 96, 112, 112]                                                  0  0
# backbond1.2.1.conv  [DepthwiseConv2d]               [None, 96, 56, 56]         'weight', [96, 1, 3, 3]                    864  5,415,872
# backbond1.2.1.norm  [BatchNorm]                     [None, 96, 56, 56]         'weight', [96]                   'bias', [96]  192  1,197,952
# backbond1.2.1.activation  [Swish]                   [None, 96, 56, 56]                                                    0  0
# backbond1.2.1  [DepthwiseConv2d_Block]              [None, 96, 56, 56]                                                    0  0
# backbond1.2.2.pool  [GlobalAvgPool2d]               [None, 96]                                                            0  0
# backbond1.2.2.squeeze  [Conv2d]                     [None, 4, 1, 1]            'weight', [4, 96, 1, 1]          'bias', [4]  388  774
# backbond1.2.2.excite  [Conv2d]                      [None, 96, 1, 1]           'weight', [96, 4, 1, 1]          'bias', [96]  480  958
# backbond1.2.2  [SqueezeExcite]                      [None, 96, 56, 56]                                                    0  0
# backbond1.2.3.conv  [Conv2d]                        [None, 24, 56, 56]         'weight', [24, 96, 1, 1]                   2,304  14,447,552
# backbond1.2.3.norm  [BatchNorm]                     [None, 24, 56, 56]         'weight', [24]                   'bias', [24]  48  294,784
# backbond1.2.3  [Conv2d_Block]                       [None, 24, 56, 56]                                                    0  0
# backbond1.2.4  [Identity]                           [None, 24, 56, 56]                                                    0  0
# backbond1.3.Identity  [Identity]                    [None, 24, 56, 56]                                                    0  0
# backbond1.3.branch2.0.conv  [Conv2d]                [None, 144, 56, 56]        'weight', [144, 24, 1, 1]                  3,456  21,672,896
# backbond1.3.branch2.0.norm  [BatchNorm]             [None, 144, 56, 56]        'weight', [144]                  'bias', [144]  288  1,800,064
# backbond1.3.branch2.0.activation  [Swish]           [None, 144, 56, 56]                                                   0  0
# backbond1.3.branch2.0  [Conv2d_Block]               [None, 144, 56, 56]                                                   0  0
# backbond1.3.branch2.1.conv  [DepthwiseConv2d]       [None, 144, 56, 56]        'weight', [144, 1, 3, 3]                   1,296  8,125,376
# backbond1.3.branch2.1.norm  [BatchNorm]             [None, 144, 56, 56]        'weight', [144]                  'bias', [144]  288  1,800,064
# backbond1.3.branch2.1.activation  [Swish]           [None, 144, 56, 56]                                                   0  0
# backbond1.3.branch2.1  [DepthwiseConv2d_Block]      [None, 144, 56, 56]                                                   0  0
# backbond1.3.branch2.2.pool  [GlobalAvgPool2d]       [None, 144]                                                           0  0
# backbond1.3.branch2.2.squeeze  [Conv2d]             [None, 6, 1, 1]            'weight', [6, 144, 1, 1]         'bias', [6]  870  1,738
# backbond1.3.branch2.2.excite  [Conv2d]              [None, 144, 1, 1]          'weight', [144, 6, 1, 1]         'bias', [144]  1,008  2,014
# backbond1.3.branch2.2  [SqueezeExcite]              [None, 144, 56, 56]                                                   0  0
# backbond1.3.branch2.3.conv  [Conv2d]                [None, 24, 56, 56]         'weight', [24, 144, 1, 1]                  3,456  21,672,896
# backbond1.3.branch2.3.norm  [BatchNorm]             [None, 24, 56, 56]         'weight', [24]                   'bias', [24]  48  294,784
# backbond1.3.branch2.3  [Conv2d_Block]               [None, 24, 56, 56]                                                    0  0
# backbond1.3.branch2.4  [Dropout]                    [None, 24, 56, 56]                                                    0  0
# backbond1.3  [ShortCut2d]                           [None, 24, 56, 56]                                                    0  0
# backbond2.0.0.conv  [Conv2d]                        [None, 144, 56, 56]        'weight', [144, 24, 1, 1]                  3,456  21,672,896
# backbond2.0.0.norm  [BatchNorm]                     [None, 144, 56, 56]        'weight', [144]                  'bias', [144]  288  1,800,064
# backbond2.0.0.activation  [Swish]                   [None, 144, 56, 56]                                                   0  0
# backbond2.0.0  [Conv2d_Block]                       [None, 144, 56, 56]                                                   0  0
# backbond2.0.1.conv  [DepthwiseConv2d]               [None, 144, 28, 28]        'weight', [144, 1, 5, 5]                   3,600  5,644,016
# backbond2.0.1.norm  [BatchNorm]                     [None, 144, 28, 28]        'weight', [144]                  'bias', [144]  288  450,016
# backbond2.0.1.activation  [Swish]                   [None, 144, 28, 28]                                                   0  0
# backbond2.0.1  [DepthwiseConv2d_Block]              [None, 144, 28, 28]                                                   0  0
# backbond2.0.2.pool  [GlobalAvgPool2d]               [None, 144]                                                           0  0
# backbond2.0.2.squeeze  [Conv2d]                     [None, 6, 1, 1]            'weight', [6, 144, 1, 1]         'bias', [6]  870  1,738
# backbond2.0.2.excite  [Conv2d]                      [None, 144, 1, 1]          'weight', [144, 6, 1, 1]         'bias', [144]  1,008  2,014
# backbond2.0.2  [SqueezeExcite]                      [None, 144, 28, 28]                                                   0  0
# backbond2.0.3.conv  [Conv2d]                        [None, 40, 28, 28]         'weight', [40, 144, 1, 1]                  5,760  9,030,896
# backbond2.0.3.norm  [BatchNorm]                     [None, 40, 28, 28]         'weight', [40]                   'bias', [40]  80  123,872
# backbond2.0.3  [Conv2d_Block]                       [None, 40, 28, 28]                                                    0  0
# backbond2.0.4  [Identity]                           [None, 40, 28, 28]                                                    0  0
# backbond2.1.Identity  [Identity]                    [None, 40, 28, 28]                                                    0  0
# backbond2.1.branch2.0.conv  [Conv2d]                [None, 240, 28, 28]        'weight', [240, 40, 1, 1]                  9,600  15,052,016
# backbond2.1.branch2.0.norm  [BatchNorm]             [None, 240, 28, 28]        'weight', [240]                  'bias', [240]  480  751,072
# backbond2.1.branch2.0.activation  [Swish]           [None, 240, 28, 28]                                                   0  0
# backbond2.1.branch2.0  [Conv2d_Block]               [None, 240, 28, 28]                                                   0  0
# backbond2.1.branch2.1.conv  [DepthwiseConv2d]       [None, 240, 28, 28]        'weight', [240, 1, 5, 5]                   6,000  9,407,216
# backbond2.1.branch2.1.norm  [BatchNorm]             [None, 240, 28, 28]        'weight', [240]                  'bias', [240]  480  751,072
# backbond2.1.branch2.1.activation  [Swish]           [None, 240, 28, 28]                                                   0  0
# backbond2.1.branch2.1  [DepthwiseConv2d_Block]      [None, 240, 28, 28]                                                   0  0
# backbond2.1.branch2.2.pool  [GlobalAvgPool2d]       [None, 240]                                                           0  0
# backbond2.1.branch2.2.squeeze  [Conv2d]             [None, 10, 1, 1]           'weight', [10, 240, 1, 1]        'bias', [10]  2,410  4,818
# backbond2.1.branch2.2.excite  [Conv2d]              [None, 240, 1, 1]          'weight', [240, 10, 1, 1]        'bias', [240]  2,640  5,278
# backbond2.1.branch2.2  [SqueezeExcite]              [None, 240, 28, 28]                                                   0  0
# backbond2.1.branch2.3.conv  [Conv2d]                [None, 40, 28, 28]         'weight', [40, 240, 1, 1]                  9,600  15,052,016
# backbond2.1.branch2.3.norm  [BatchNorm]             [None, 40, 28, 28]         'weight', [40]                   'bias', [40]  80  123,872
# backbond2.1.branch2.3  [Conv2d_Block]               [None, 40, 28, 28]                                                    0  0
# backbond2.1.branch2.4  [Dropout]                    [None, 40, 28, 28]                                                    0  0
# backbond2.1  [ShortCut2d]                           [None, 40, 28, 28]                                                    0  0
# backbond2.2.0.conv  [Conv2d]                        [None, 240, 28, 28]        'weight', [240, 40, 1, 1]                  9,600  15,052,016
# backbond2.2.0.norm  [BatchNorm]                     [None, 240, 28, 28]        'weight', [240]                  'bias', [240]  480  751,072
# backbond2.2.0.activation  [Swish]                   [None, 240, 28, 28]                                                   0  0
# backbond2.2.0  [Conv2d_Block]                       [None, 240, 28, 28]                                                   0  0
# backbond2.2.1.conv  [DepthwiseConv2d]               [None, 240, 14, 14]        'weight', [240, 1, 3, 3]                   2,160  846,524
# backbond2.2.1.norm  [BatchNorm]                     [None, 240, 14, 14]        'weight', [240]                  'bias', [240]  480  187,768
# backbond2.2.1.activation  [Swish]                   [None, 240, 14, 14]                                                   0  0
# backbond2.2.1  [DepthwiseConv2d_Block]              [None, 240, 14, 14]                                                   0  0
# backbond2.2.2.pool  [GlobalAvgPool2d]               [None, 240]                                                           0  0
# backbond2.2.2.squeeze  [Conv2d]                     [None, 10, 1, 1]           'weight', [10, 240, 1, 1]        'bias', [10]  2,410  4,818
# backbond2.2.2.excite  [Conv2d]                      [None, 240, 1, 1]          'weight', [240, 10, 1, 1]        'bias', [240]  2,640  5,278
# backbond2.2.2  [SqueezeExcite]                      [None, 240, 14, 14]                                                   0  0
# backbond2.2.3.conv  [Conv2d]                        [None, 80, 14, 14]         'weight', [80, 240, 1, 1]                  19,200  7,526,204
# backbond2.2.3.norm  [BatchNorm]                     [None, 80, 14, 14]         'weight', [80]                   'bias', [80]  160  62,328
# backbond2.2.3  [Conv2d_Block]                       [None, 80, 14, 14]                                                    0  0
# backbond2.2.4  [Identity]                           [None, 80, 14, 14]                                                    0  0
# backbond2.3.Identity  [Identity]                    [None, 80, 14, 14]                                                    0  0
# backbond2.3.branch2.0.conv  [Conv2d]                [None, 480, 14, 14]        'weight', [480, 80, 1, 1]                  38,400  15,052,604
# backbond2.3.branch2.0.norm  [BatchNorm]             [None, 480, 14, 14]        'weight', [480]                  'bias', [480]  960  375,928
# backbond2.3.branch2.0.activation  [Swish]           [None, 480, 14, 14]                                                   0  0
# backbond2.3.branch2.0  [Conv2d_Block]               [None, 480, 14, 14]                                                   0  0
# backbond2.3.branch2.1.conv  [DepthwiseConv2d]       [None, 480, 14, 14]        'weight', [480, 1, 3, 3]                   4,320  1,693,244
# backbond2.3.branch2.1.norm  [BatchNorm]             [None, 480, 14, 14]        'weight', [480]                  'bias', [480]  960  375,928
# backbond2.3.branch2.1.activation  [Swish]           [None, 480, 14, 14]                                                   0  0
# backbond2.3.branch2.1  [DepthwiseConv2d_Block]      [None, 480, 14, 14]                                                   0  0
# backbond2.3.branch2.2.pool  [GlobalAvgPool2d]       [None, 480]                                                           0  0
# backbond2.3.branch2.2.squeeze  [Conv2d]             [None, 20, 1, 1]           'weight', [20, 480, 1, 1]        'bias', [20]  9,620  19,238
# backbond2.3.branch2.2.excite  [Conv2d]              [None, 480, 1, 1]          'weight', [480, 20, 1, 1]        'bias', [480]  10,080  20,158
# backbond2.3.branch2.2  [SqueezeExcite]              [None, 480, 14, 14]                                                   0  0
# backbond2.3.branch2.3.conv  [Conv2d]                [None, 80, 14, 14]         'weight', [80, 480, 1, 1]                  38,400  15,052,604
# backbond2.3.branch2.3.norm  [BatchNorm]             [None, 80, 14, 14]         'weight', [80]                   'bias', [80]  160  62,328
# backbond2.3.branch2.3  [Conv2d_Block]               [None, 80, 14, 14]                                                    0  0
# backbond2.3.branch2.4  [Dropout]                    [None, 80, 14, 14]                                                    0  0
# backbond2.3  [ShortCut2d]                           [None, 80, 14, 14]                                                    0  0
# backbond2.4.Identity  [Identity]                    [None, 80, 14, 14]                                                    0  0
# backbond2.4.branch2.0.conv  [Conv2d]                [None, 480, 14, 14]        'weight', [480, 80, 1, 1]                  38,400  15,052,604
# backbond2.4.branch2.0.norm  [BatchNorm]             [None, 480, 14, 14]        'weight', [480]                  'bias', [480]  960  375,928
# backbond2.4.branch2.0.activation  [Swish]           [None, 480, 14, 14]                                                   0  0
# backbond2.4.branch2.0  [Conv2d_Block]               [None, 480, 14, 14]                                                   0  0
# backbond2.4.branch2.1.conv  [DepthwiseConv2d]       [None, 480, 14, 14]        'weight', [480, 1, 3, 3]                   4,320  1,693,244
# backbond2.4.branch2.1.norm  [BatchNorm]             [None, 480, 14, 14]        'weight', [480]                  'bias', [480]  960  375,928
# backbond2.4.branch2.1.activation  [Swish]           [None, 480, 14, 14]                                                   0  0
# backbond2.4.branch2.1  [DepthwiseConv2d_Block]      [None, 480, 14, 14]                                                   0  0
# backbond2.4.branch2.2.pool  [GlobalAvgPool2d]       [None, 480]                                                           0  0
# backbond2.4.branch2.2.squeeze  [Conv2d]             [None, 20, 1, 1]           'weight', [20, 480, 1, 1]        'bias', [20]  9,620  19,238
# backbond2.4.branch2.2.excite  [Conv2d]              [None, 480, 1, 1]          'weight', [480, 20, 1, 1]        'bias', [480]  10,080  20,158
# backbond2.4.branch2.2  [SqueezeExcite]              [None, 480, 14, 14]                                                   0  0
# backbond2.4.branch2.3.conv  [Conv2d]                [None, 80, 14, 14]         'weight', [80, 480, 1, 1]                  38,400  15,052,604
# backbond2.4.branch2.3.norm  [BatchNorm]             [None, 80, 14, 14]         'weight', [80]                   'bias', [80]  160  62,328
# backbond2.4.branch2.3  [Conv2d_Block]               [None, 80, 14, 14]                                                    0  0
# backbond2.4.branch2.4  [Dropout]                    [None, 80, 14, 14]                                                    0  0
# backbond2.4  [ShortCut2d]                           [None, 80, 14, 14]                                                    0  0
# backbond2.5.0.conv  [Conv2d]                        [None, 480, 14, 14]        'weight', [480, 80, 1, 1]                  38,400  15,052,604
# backbond2.5.0.norm  [BatchNorm]                     [None, 480, 14, 14]        'weight', [480]                  'bias', [480]  960  375,928
# backbond2.5.0.activation  [Swish]                   [None, 480, 14, 14]                                                   0  0
# backbond2.5.0  [Conv2d_Block]                       [None, 480, 14, 14]                                                   0  0
# backbond2.5.1.conv  [DepthwiseConv2d]               [None, 480, 14, 14]        'weight', [480, 1, 5, 5]                   12,000  4,703,804
# backbond2.5.1.norm  [BatchNorm]                     [None, 480, 14, 14]        'weight', [480]                  'bias', [480]  960  375,928
# backbond2.5.1.activation  [Swish]                   [None, 480, 14, 14]                                                   0  0
# backbond2.5.1  [DepthwiseConv2d_Block]              [None, 480, 14, 14]                                                   0  0
# backbond2.5.2.pool  [GlobalAvgPool2d]               [None, 480]                                                           0  0
# backbond2.5.2.squeeze  [Conv2d]                     [None, 20, 1, 1]           'weight', [20, 480, 1, 1]        'bias', [20]  9,620  19,238
# backbond2.5.2.excite  [Conv2d]                      [None, 480, 1, 1]          'weight', [480, 20, 1, 1]        'bias', [480]  10,080  20,158
# backbond2.5.2  [SqueezeExcite]                      [None, 480, 14, 14]                                                   0  0
# backbond2.5.3.conv  [Conv2d]                        [None, 112, 14, 14]        'weight', [112, 480, 1, 1]                 53,760  21,073,724
# backbond2.5.3.norm  [BatchNorm]                     [None, 112, 14, 14]        'weight', [112]                  'bias', [112]  224  87,416
# backbond2.5.3  [Conv2d_Block]                       [None, 112, 14, 14]                                                   0  0
# backbond2.5.4  [Identity]                           [None, 112, 14, 14]                                                   0  0
# backbond2.6.Identity  [Identity]                    [None, 112, 14, 14]                                                   0  0
# backbond2.6.branch2.0.conv  [Conv2d]                [None, 672, 14, 14]        'weight', [672, 112, 1, 1]                 75,264  29,503,292
# backbond2.6.branch2.0.norm  [BatchNorm]             [None, 672, 14, 14]        'weight', [672]                  'bias', [672]  1,344  526,456
# backbond2.6.branch2.0.activation  [Swish]           [None, 672, 14, 14]                                                   0  0
# backbond2.6.branch2.0  [Conv2d_Block]               [None, 672, 14, 14]                                                   0  0
# backbond2.6.branch2.1.conv  [DepthwiseConv2d]       [None, 672, 14, 14]        'weight', [672, 1, 5, 5]                   16,800  6,585,404
# backbond2.6.branch2.1.norm  [BatchNorm]             [None, 672, 14, 14]        'weight', [672]                  'bias', [672]  1,344  526,456
# backbond2.6.branch2.1.activation  [Swish]           [None, 672, 14, 14]                                                   0  0
# backbond2.6.branch2.1  [DepthwiseConv2d_Block]      [None, 672, 14, 14]                                                   0  0
# backbond2.6.branch2.2.pool  [GlobalAvgPool2d]       [None, 672]                                                           0  0
# backbond2.6.branch2.2.squeeze  [Conv2d]             [None, 28, 1, 1]           'weight', [28, 672, 1, 1]        'bias', [28]  18,844  37,686
# backbond2.6.branch2.2.excite  [Conv2d]              [None, 672, 1, 1]          'weight', [672, 28, 1, 1]        'bias', [672]  19,488  38,974
# backbond2.6.branch2.2  [SqueezeExcite]              [None, 672, 14, 14]                                                   0  0
# backbond2.6.branch2.3.conv  [Conv2d]                [None, 112, 14, 14]        'weight', [112, 672, 1, 1]                 75,264  29,503,292
# backbond2.6.branch2.3.norm  [BatchNorm]             [None, 112, 14, 14]        'weight', [112]                  'bias', [112]  224  87,416
# backbond2.6.branch2.3  [Conv2d_Block]               [None, 112, 14, 14]                                                   0  0
# backbond2.6.branch2.4  [Dropout]                    [None, 112, 14, 14]                                                   0  0
# backbond2.6  [ShortCut2d]                           [None, 112, 14, 14]                                                   0  0
# backbond2.7.Identity  [Identity]                    [None, 112, 14, 14]                                                   0  0
# backbond2.7.branch2.0.conv  [Conv2d]                [None, 672, 14, 14]        'weight', [672, 112, 1, 1]                 75,264  29,503,292
# backbond2.7.branch2.0.norm  [BatchNorm]             [None, 672, 14, 14]        'weight', [672]                  'bias', [672]  1,344  526,456
# backbond2.7.branch2.0.activation  [Swish]           [None, 672, 14, 14]                                                   0  0
# backbond2.7.branch2.0  [Conv2d_Block]               [None, 672, 14, 14]                                                   0  0
# backbond2.7.branch2.1.conv  [DepthwiseConv2d]       [None, 672, 14, 14]        'weight', [672, 1, 5, 5]                   16,800  6,585,404
# backbond2.7.branch2.1.norm  [BatchNorm]             [None, 672, 14, 14]        'weight', [672]                  'bias', [672]  1,344  526,456
# backbond2.7.branch2.1.activation  [Swish]           [None, 672, 14, 14]                                                   0  0
# backbond2.7.branch2.1  [DepthwiseConv2d_Block]      [None, 672, 14, 14]                                                   0  0
# backbond2.7.branch2.2.pool  [GlobalAvgPool2d]       [None, 672]                                                           0  0
# backbond2.7.branch2.2.squeeze  [Conv2d]             [None, 28, 1, 1]           'weight', [28, 672, 1, 1]        'bias', [28]  18,844  37,686
# backbond2.7.branch2.2.excite  [Conv2d]              [None, 672, 1, 1]          'weight', [672, 28, 1, 1]        'bias', [672]  19,488  38,974
# backbond2.7.branch2.2  [SqueezeExcite]              [None, 672, 14, 14]                                                   0  0
# backbond2.7.branch2.3.conv  [Conv2d]                [None, 112, 14, 14]        'weight', [112, 672, 1, 1]                 75,264  29,503,292
# backbond2.7.branch2.3.norm  [BatchNorm]             [None, 112, 14, 14]        'weight', [112]                  'bias', [112]  224  87,416
# backbond2.7.branch2.3  [Conv2d_Block]               [None, 112, 14, 14]                                                   0  0
# backbond2.7.branch2.4  [Dropout]                    [None, 112, 14, 14]                                                   0  0
# backbond2.7  [ShortCut2d]                           [None, 112, 14, 14]                                                   0  0
# aspp.0.conv1.conv  [Conv2d]                         [None, 256, 14, 14]        'weight', [256, 112, 1, 1]                 28,672  11,239,228
# aspp.0.conv1.norm  [BatchNorm]                      [None, 256, 14, 14]        'weight', [256]                  'bias', [256]  512  200,312
# aspp.0.conv1  [Conv2d_Block]                        [None, 256, 14, 14]                                                   0  0
# aspp.0.aspp_dilation0.conv  [Conv2d]                [None, 256, 14, 14]        'weight', [256, 112, 3, 3]                 258,048  101,154,620
# aspp.0.aspp_dilation0.norm  [BatchNorm]             [None, 256, 14, 14]        'weight', [256]                  'bias', [256]  512  200,312
# aspp.0.aspp_dilation0  [Conv2d_Block]               [None, 256, 14, 14]                                                   0  0
# aspp.0.aspp_dilation1.conv  [Conv2d]                [None, 256, 14, 14]        'weight', [256, 112, 3, 3]                 258,048  101,154,620
# aspp.0.aspp_dilation1.norm  [BatchNorm]             [None, 256, 14, 14]        'weight', [256]                  'bias', [256]  512  200,312
# aspp.0.aspp_dilation1  [Conv2d_Block]               [None, 256, 14, 14]                                                   0  0
# aspp.0.aspp_dilation2.conv  [Conv2d]                [None, 256, 14, 14]        'weight', [256, 112, 3, 3]                 258,048  101,154,620
# aspp.0.aspp_dilation2.norm  [BatchNorm]             [None, 256, 14, 14]        'weight', [256]                  'bias', [256]  512  200,312
# aspp.0.aspp_dilation2  [Conv2d_Block]               [None, 256, 14, 14]                                                   0  0
# aspp.0.aspp_dilation3.conv  [Conv2d]                [None, 256, 14, 14]        'weight', [256, 112, 3, 3]                 258,048  101,154,620
# aspp.0.aspp_dilation3.norm  [BatchNorm]             [None, 256, 14, 14]        'weight', [256]                  'bias', [256]  512  200,312
# aspp.0.aspp_dilation3  [Conv2d_Block]               [None, 256, 14, 14]                                                   0  0
# aspp.0.aspp_pooling.0  [AdaptiveAvgPool2d]          [None, 112, 1, 1]                                                     0  0
# aspp.0.aspp_pooling.1  [Conv2d]                     [None, 256, 1, 1]          'weight', [256, 112, 1, 1]                 28,672  57,343
# aspp.0.aspp_pooling.2  [Upsampling2d]               [None, 256, 14, 14]                                                   0  0
# aspp.0  [ShortCut2d]                                [None, 1536, 14, 14]                                                  0  0
# aspp.1.conv  [Conv2d]                               [None, 256, 14, 14]        'weight', [256, 1536, 1, 1]                393,216  154,140,476
# aspp.1.norm  [BatchNorm]                            [None, 256, 14, 14]        'weight', [256]                  'bias', [256]  512  200,312
# aspp.1.activation  [Relu]                           [None, 256, 14, 14]                                                   0  0
# aspp.1  [Conv2d_Block]                              [None, 256, 14, 14]                                                   0  0
# low_level_conv.conv  [Conv2d]                       [None, 48, 56, 56]         'weight', [48, 24, 1, 1]                   1,152  7,222,208
# low_level_conv.norm  [BatchNorm]                    [None, 48, 56, 56]         'weight', [48]                   'bias', [48]  96  595,840
# low_level_conv.activation  [LeakyRelu]              [None, 48, 56, 56]                                                    0  0
# low_level_conv  [Conv2d_Block]                      [None, 48, 56, 56]                                                    0  0
# decoder.0.conv  [DepthwiseConv2d]                   [None, 152, 56, 56]        'weight', [152, 2, 3, 3]                   2,736  17,157,056
# decoder.0.norm  [BatchNorm]                         [None, 152, 56, 56]        'weight', [152]                  'bias', [152]  304  1,900,416
# decoder.0.activation  [LeakyRelu]                   [None, 152, 56, 56]                                                   0  0
# decoder.0  [DepthwiseConv2d_Block]                  [None, 152, 56, 56]                                                   0  0
# decoder.1.conv  [DepthwiseConv2d]                   [None, 152, 56, 56]        'weight', [152, 1, 3, 3]                   1,368  8,576,960
# decoder.1.norm  [BatchNorm]                         [None, 152, 56, 56]        'weight', [152]                  'bias', [152]  304  1,900,416
# decoder.1.activation  [LeakyRelu]                   [None, 152, 56, 56]                                                   0  0
# decoder.1  [DepthwiseConv2d_Block]                  [None, 152, 56, 56]                                                   0  0
# decoder.2  [Conv2d]                                 [None, 2, 56, 56]          'weight', [2, 152, 1, 1]                   304  1,903,552
# decoder.3  [SoftMax]                                [None, 2, 56, 56]                                                     0  0
# ================================================================
# Total params: 2,343,896
# Trainable params: 1,492,088
# Non-trainable params: 851,808
# Total MACC: 560,705,216
# Total FLOPs: 1.12114 GFLOPs
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 245.47
# Params size (MB): 8.94
# Estimated Total Size (MB): 254.98
# ----------------------------------------------------------------

# %% [markdown]
# 所有基於預訓練骨幹的模型都最好先將大部分的預訓練區域權重凍結，然後再依照訓練狀況逐步開放，因此我們將整個deeplab模型設為可訓練，然後將主骨幹部分設為不可訓練，但是backbond2的最後一層(backbond2.0.7)是開放學習的。

# %%
#deeplabv3.load_model('Models/deeplab_seg.pth.tar')
deeplabv3.model.trainable=True
deeplabv3.model.backbond1.trainable=False
deeplabv3.model.backbond2.trainable=False
# Out:
# 851808 parameters have set trainable
# 19090 parameters have set untrainable
# 832718 parameters have set untrainable

# %% [markdown]
# 在損失函數的選取部分，我們採用複合的損失函數策略。Dice loss跟F1 Score概念有點像(各位可以參考實作:鑑黃大師)，它是權衡了準確率與召回率的一個指標，它著重在各個類別層級的像素預測吻合程度。至於大家熟悉的交叉熵，則是像素層級來判斷預測機率與實際答案之差異。兩種損失混和在一起可以獲得較全面的收斂效果。其中Dice loss的好處在於收斂非常快，但是它畢竟是類別層級，所以到了訓練中後期會比較後繼無力，這時候搭配像素層級的交叉熵，正好兩者互補。
#
# 此外，也推薦使用曠視在UnitBox這篇論文所提出的IOU Loss (Iouloss=-ln(iou))，他利用對數後取負值將原本非連續不可微分的IOU轉化成連續可微分的損失函數，它直接針對IOU做優化，所以對於會發生收斂停滯這類問題時也非常有用，但由於它本身的形式，當IOU很小時它的數值會過大且不穩定，所以比較適合與其他損失函數一起搭配使用。此外實務上，如果類別間比例非常不均衡，建議還可以加入Focal Loss，來解決比例不均衡的問題。
#
# 至於在評價函數上，我們加入了像素正確率(正確預測像素數/非背景值得像素總數)以及iou(預測值與實際值交集/預測值與實際值聯集)，兩者分子的意義是一樣的，iou的分母會大一點，所以整體數值應該會略低於像素正確率。
#
# 至於學習速率方面，請不要設得太大，建議設定為1e-4上下，否則很容易發生損失函數收斂很快然後又反彈升高的狀況。使用較低的學習速率訓練，可以獲得較穩定的結果。訓練時如果有loss持續下降但是IOU沒有顯著回升的狀況，也請保持點耐心，這是正常現象，模型要訓練到一個臨界點後，IOU才會有明顯的變化。

# %%
deeplabv3.with_optimizer(optimizer='Ranger',lr=1e-3,betas=(0.7, 0.999))\
    .with_loss(DiceLoss)\
    .with_loss(CrossEntropyLoss(),loss_weight=4)\
    .with_loss(IoULoss,0.5,start_epoch=3)\
    .with_loss(FocalLoss,start_epoch=5)\
    .with_metric(pixel_accuracy,name='pixel_accuracy')\
    .with_metric(iou,name='iou')\
    .with_regularizer('l2',reg_weight=1e-6)\
    .with_constraint('min_max_norm')\
    .with_learning_rate_scheduler(reduce_lr_on_plateau,monitor='iou',mode='max',factor=0.5,patience=1,cooldown=1,threshold=5e-5,warmup=0)\
    .with_model_save_path('Models/deeplab_seg.pth')\
    .with_callbacks(SegTileImageCallback(100,reverse_image_transform=data_provider.reverse_image_transform,background=(255,128,255)))\
    .with_automatic_mixed_precision_training()


deeplabv3.summary()

#在模型中設定
#with_optimizer 設定優化器為Ranger
#with_loss(DiceLoss) 加入Dice loss損失函數(類別層級)
#with_loss(CrossEntropyLoss,2)加入交叉熵作為損失函數(像素層級)
#with_loss(IouLoss,1)加入iou損失作為損失函數(類別層級) 直接針對iou優化

#建議訓練的後半段可以加入
#with_loss(FocalLoss,2)加入FocalLoss作為損失函數(像素層級)解決類別不均衡問題

#with_metric(pixel_accuracy) 加入像素正確率metrics
#with_metric(iou,name='iou') 加入iou作為metrics
#with_regularizer('l2')\ 加入l2正則
#with_constraint('max_min_norm')\ 加入max_min_norm權重正則
#with_learning_rate_scheduler(reduce_lr_on_plateau) 加入reduce_lr_on_plateau學習率變化原則(指標不再變動時，學習率下降)
#with_model_save_path('Models/deeplab_seg.pth') 設定模型存檔路徑
#with_callbacks 加入SegTileImageCallback來繪製比較用的tile images
# Out:
# DiceLoss( output: Tensor[(None,)] , target: Tensor[(None,)] ) -> loss: Tensor[(None,)]
# CrossEntropyLoss( output: Tensor[(None,)] , target: Tensor[(None,)] ) -> loss: Tensor[(None,)]
# IoULoss( output: Tensor[(None,)] , target: Tensor[(None,)] ) -> loss: Tensor[(None,)]
# FocalLoss( output: Tensor[(None,)] , target: Tensor[(None,)] ) -> loss: Tensor[(None,)]
# pixel_accuracy( output: Tensor[(None,)] , target: Tensor[(None,)] ) -> output: Tensor[(None,)]
# iou( output: Tensor[(None,)] , target: Tensor[(None,)] ) -> output: Tensor[(None,)]
# Automatic Mixed Precision:Turn On.
# --------------------------------------------------------------------------------------------------------------------------------
#                    Layer (type)                     Output Shape               Weight                           Bias      Param #   FLOPS #
# ==============================================================================
# backbond1.0.conv  [Conv2d]                          [None, 32, 112, 112]       'weight', [32, 3, 3, 3]                    864  21,663,488
# backbond1.0.norm  [BatchNorm]                       [None, 32, 112, 112]       'weight', [32]                   'bias', [32]  64  1,580,544
# backbond1.0.activation  [Swish]                     [None, 32, 112, 112]                                                  0  0
# backbond1.0  [Conv2d_Block]                         [None, 32, 112, 112]                                                  0  0
# backbond1.1.0.conv  [DepthwiseConv2d]               [None, 32, 112, 112]       'weight', [32, 1, 3, 3]                    288  7,212,800
# backbond1.1.0.norm  [BatchNorm]                     [None, 32, 112, 112]       'weight', [32]                   'bias', [32]  64  1,580,544
# backbond1.1.0.activation  [Swish]                   [None, 32, 112, 112]                                                  0  0
# backbond1.1.0  [DepthwiseConv2d_Block]              [None, 32, 112, 112]                                                  0  0
# backbond1.1.1.pool  [GlobalAvgPool2d]               [None, 32]                                                            0  0
# backbond1.1.1.squeeze  [Conv2d]                     [None, 8, 1, 1]            'weight', [8, 32, 1, 1]          'bias', [8]  264  526
# backbond1.1.1.excite  [Conv2d]                      [None, 32, 1, 1]           'weight', [32, 8, 1, 1]          'bias', [32]  288  574
# backbond1.1.1  [SqueezeExcite]                      [None, 32, 112, 112]                                                  0  0
# backbond1.1.2.conv  [Conv2d]                        [None, 16, 112, 112]       'weight', [16, 32, 1, 1]                   512  12,832,512
# backbond1.1.2.norm  [BatchNorm]                     [None, 16, 112, 112]       'weight', [16]                   'bias', [16]  32  777,728
# backbond1.1.2  [Conv2d_Block]                       [None, 16, 112, 112]                                                  0  0
# backbond1.1.3  [Identity]                           [None, 16, 112, 112]                                                  0  0
# backbond1.2.0.conv  [Conv2d]                        [None, 96, 112, 112]       'weight', [96, 16, 1, 1]                   1,536  38,522,624
# backbond1.2.0.norm  [BatchNorm]                     [None, 96, 112, 112]       'weight', [96]                   'bias', [96]  192  4,791,808
# backbond1.2.0.activation  [Swish]                   [None, 96, 112, 112]                                                  0  0
# backbond1.2.0  [Conv2d_Block]                       [None, 96, 112, 112]                                                  0  0
# backbond1.2.1.conv  [DepthwiseConv2d]               [None, 96, 56, 56]         'weight', [96, 1, 3, 3]                    864  5,415,872
# backbond1.2.1.norm  [BatchNorm]                     [None, 96, 56, 56]         'weight', [96]                   'bias', [96]  192  1,197,952
# backbond1.2.1.activation  [Swish]                   [None, 96, 56, 56]                                                    0  0
# backbond1.2.1  [DepthwiseConv2d_Block]              [None, 96, 56, 56]                                                    0  0
# backbond1.2.2.pool  [GlobalAvgPool2d]               [None, 96]                                                            0  0
# backbond1.2.2.squeeze  [Conv2d]                     [None, 4, 1, 1]            'weight', [4, 96, 1, 1]          'bias', [4]  388  774
# backbond1.2.2.excite  [Conv2d]                      [None, 96, 1, 1]           'weight', [96, 4, 1, 1]          'bias', [96]  480  958
# backbond1.2.2  [SqueezeExcite]                      [None, 96, 56, 56]                                                    0  0
# backbond1.2.3.conv  [Conv2d]                        [None, 24, 56, 56]         'weight', [24, 96, 1, 1]                   2,304  14,447,552
# backbond1.2.3.norm  [BatchNorm]                     [None, 24, 56, 56]         'weight', [24]                   'bias', [24]  48  294,784
# backbond1.2.3  [Conv2d_Block]                       [None, 24, 56, 56]                                                    0  0
# backbond1.2.4  [Identity]                           [None, 24, 56, 56]                                                    0  0
# backbond1.3.Identity  [Identity]                    [None, 24, 56, 56]                                                    0  0
# backbond1.3.branch2.0.conv  [Conv2d]                [None, 144, 56, 56]        'weight', [144, 24, 1, 1]                  3,456  21,672,896
# backbond1.3.branch2.0.norm  [BatchNorm]             [None, 144, 56, 56]        'weight', [144]                  'bias', [144]  288  1,800,064
# backbond1.3.branch2.0.activation  [Swish]           [None, 144, 56, 56]                                                   0  0
# backbond1.3.branch2.0  [Conv2d_Block]               [None, 144, 56, 56]                                                   0  0
# backbond1.3.branch2.1.conv  [DepthwiseConv2d]       [None, 144, 56, 56]        'weight', [144, 1, 3, 3]                   1,296  8,125,376
# backbond1.3.branch2.1.norm  [BatchNorm]             [None, 144, 56, 56]        'weight', [144]                  'bias', [144]  288  1,800,064
# backbond1.3.branch2.1.activation  [Swish]           [None, 144, 56, 56]                                                   0  0
# backbond1.3.branch2.1  [DepthwiseConv2d_Block]      [None, 144, 56, 56]                                                   0  0
# backbond1.3.branch2.2.pool  [GlobalAvgPool2d]       [None, 144]                                                           0  0
# backbond1.3.branch2.2.squeeze  [Conv2d]             [None, 6, 1, 1]            'weight', [6, 144, 1, 1]         'bias', [6]  870  1,738
# backbond1.3.branch2.2.excite  [Conv2d]              [None, 144, 1, 1]          'weight', [144, 6, 1, 1]         'bias', [144]  1,008  2,014
# backbond1.3.branch2.2  [SqueezeExcite]              [None, 144, 56, 56]                                                   0  0
# backbond1.3.branch2.3.conv  [Conv2d]                [None, 24, 56, 56]         'weight', [24, 144, 1, 1]                  3,456  21,672,896
# backbond1.3.branch2.3.norm  [BatchNorm]             [None, 24, 56, 56]         'weight', [24]                   'bias', [24]  48  294,784
# backbond1.3.branch2.3  [Conv2d_Block]               [None, 24, 56, 56]                                                    0  0
# backbond1.3.branch2.4  [Dropout]                    [None, 24, 56, 56]                                                    0  0
# backbond1.3  [ShortCut2d]                           [None, 24, 56, 56]                                                    0  0
# backbond2.0.0.conv  [Conv2d]                        [None, 144, 56, 56]        'weight', [144, 24, 1, 1]                  3,456  21,672,896
# backbond2.0.0.norm  [BatchNorm]                     [None, 144, 56, 56]        'weight', [144]                  'bias', [144]  288  1,800,064
# backbond2.0.0.activation  [Swish]                   [None, 144, 56, 56]                                                   0  0
# backbond2.0.0  [Conv2d_Block]                       [None, 144, 56, 56]                                                   0  0
# backbond2.0.1.conv  [DepthwiseConv2d]               [None, 144, 28, 28]        'weight', [144, 1, 5, 5]                   3,600  5,644,016
# backbond2.0.1.norm  [BatchNorm]                     [None, 144, 28, 28]        'weight', [144]                  'bias', [144]  288  450,016
# backbond2.0.1.activation  [Swish]                   [None, 144, 28, 28]                                                   0  0
# backbond2.0.1  [DepthwiseConv2d_Block]              [None, 144, 28, 28]                                                   0  0
# backbond2.0.2.pool  [GlobalAvgPool2d]               [None, 144]                                                           0  0
# backbond2.0.2.squeeze  [Conv2d]                     [None, 6, 1, 1]            'weight', [6, 144, 1, 1]         'bias', [6]  870  1,738
# backbond2.0.2.excite  [Conv2d]                      [None, 144, 1, 1]          'weight', [144, 6, 1, 1]         'bias', [144]  1,008  2,014
# backbond2.0.2  [SqueezeExcite]                      [None, 144, 28, 28]                                                   0  0
# backbond2.0.3.conv  [Conv2d]                        [None, 40, 28, 28]         'weight', [40, 144, 1, 1]                  5,760  9,030,896
# backbond2.0.3.norm  [BatchNorm]                     [None, 40, 28, 28]         'weight', [40]                   'bias', [40]  80  123,872
# backbond2.0.3  [Conv2d_Block]                       [None, 40, 28, 28]                                                    0  0
# backbond2.0.4  [Identity]                           [None, 40, 28, 28]                                                    0  0
# backbond2.1.Identity  [Identity]                    [None, 40, 28, 28]                                                    0  0
# backbond2.1.branch2.0.conv  [Conv2d]                [None, 240, 28, 28]        'weight', [240, 40, 1, 1]                  9,600  15,052,016
# backbond2.1.branch2.0.norm  [BatchNorm]             [None, 240, 28, 28]        'weight', [240]                  'bias', [240]  480  751,072
# backbond2.1.branch2.0.activation  [Swish]           [None, 240, 28, 28]                                                   0  0
# backbond2.1.branch2.0  [Conv2d_Block]               [None, 240, 28, 28]                                                   0  0
# backbond2.1.branch2.1.conv  [DepthwiseConv2d]       [None, 240, 28, 28]        'weight', [240, 1, 5, 5]                   6,000  9,407,216
# backbond2.1.branch2.1.norm  [BatchNorm]             [None, 240, 28, 28]        'weight', [240]                  'bias', [240]  480  751,072
# backbond2.1.branch2.1.activation  [Swish]           [None, 240, 28, 28]                                                   0  0
# backbond2.1.branch2.1  [DepthwiseConv2d_Block]      [None, 240, 28, 28]                                                   0  0
# backbond2.1.branch2.2.pool  [GlobalAvgPool2d]       [None, 240]                                                           0  0
# backbond2.1.branch2.2.squeeze  [Conv2d]             [None, 10, 1, 1]           'weight', [10, 240, 1, 1]        'bias', [10]  2,410  4,818
# backbond2.1.branch2.2.excite  [Conv2d]              [None, 240, 1, 1]          'weight', [240, 10, 1, 1]        'bias', [240]  2,640  5,278
# backbond2.1.branch2.2  [SqueezeExcite]              [None, 240, 28, 28]                                                   0  0
# backbond2.1.branch2.3.conv  [Conv2d]                [None, 40, 28, 28]         'weight', [40, 240, 1, 1]                  9,600  15,052,016
# backbond2.1.branch2.3.norm  [BatchNorm]             [None, 40, 28, 28]         'weight', [40]                   'bias', [40]  80  123,872
# backbond2.1.branch2.3  [Conv2d_Block]               [None, 40, 28, 28]                                                    0  0
# backbond2.1.branch2.4  [Dropout]                    [None, 40, 28, 28]                                                    0  0
# backbond2.1  [ShortCut2d]                           [None, 40, 28, 28]                                                    0  0
# backbond2.2.0.conv  [Conv2d]                        [None, 240, 28, 28]        'weight', [240, 40, 1, 1]                  9,600  15,052,016
# backbond2.2.0.norm  [BatchNorm]                     [None, 240, 28, 28]        'weight', [240]                  'bias', [240]  480  751,072
# backbond2.2.0.activation  [Swish]                   [None, 240, 28, 28]                                                   0  0
# backbond2.2.0  [Conv2d_Block]                       [None, 240, 28, 28]                                                   0  0
# backbond2.2.1.conv  [DepthwiseConv2d]               [None, 240, 14, 14]        'weight', [240, 1, 3, 3]                   2,160  846,524
# backbond2.2.1.norm  [BatchNorm]                     [None, 240, 14, 14]        'weight', [240]                  'bias', [240]  480  187,768
# backbond2.2.1.activation  [Swish]                   [None, 240, 14, 14]                                                   0  0
# backbond2.2.1  [DepthwiseConv2d_Block]              [None, 240, 14, 14]                                                   0  0
# backbond2.2.2.pool  [GlobalAvgPool2d]               [None, 240]                                                           0  0
# backbond2.2.2.squeeze  [Conv2d]                     [None, 10, 1, 1]           'weight', [10, 240, 1, 1]        'bias', [10]  2,410  4,818
# backbond2.2.2.excite  [Conv2d]                      [None, 240, 1, 1]          'weight', [240, 10, 1, 1]        'bias', [240]  2,640  5,278
# backbond2.2.2  [SqueezeExcite]                      [None, 240, 14, 14]                                                   0  0
# backbond2.2.3.conv  [Conv2d]                        [None, 80, 14, 14]         'weight', [80, 240, 1, 1]                  19,200  7,526,204
# backbond2.2.3.norm  [BatchNorm]                     [None, 80, 14, 14]         'weight', [80]                   'bias', [80]  160  62,328
# backbond2.2.3  [Conv2d_Block]                       [None, 80, 14, 14]                                                    0  0
# backbond2.2.4  [Identity]                           [None, 80, 14, 14]                                                    0  0
# backbond2.3.Identity  [Identity]                    [None, 80, 14, 14]                                                    0  0
# backbond2.3.branch2.0.conv  [Conv2d]                [None, 480, 14, 14]        'weight', [480, 80, 1, 1]                  38,400  15,052,604
# backbond2.3.branch2.0.norm  [BatchNorm]             [None, 480, 14, 14]        'weight', [480]                  'bias', [480]  960  375,928
# backbond2.3.branch2.0.activation  [Swish]           [None, 480, 14, 14]                                                   0  0
# backbond2.3.branch2.0  [Conv2d_Block]               [None, 480, 14, 14]                                                   0  0
# backbond2.3.branch2.1.conv  [DepthwiseConv2d]       [None, 480, 14, 14]        'weight', [480, 1, 3, 3]                   4,320  1,693,244
# backbond2.3.branch2.1.norm  [BatchNorm]             [None, 480, 14, 14]        'weight', [480]                  'bias', [480]  960  375,928
# backbond2.3.branch2.1.activation  [Swish]           [None, 480, 14, 14]                                                   0  0
# backbond2.3.branch2.1  [DepthwiseConv2d_Block]      [None, 480, 14, 14]                                                   0  0
# backbond2.3.branch2.2.pool  [GlobalAvgPool2d]       [None, 480]                                                           0  0
# backbond2.3.branch2.2.squeeze  [Conv2d]             [None, 20, 1, 1]           'weight', [20, 480, 1, 1]        'bias', [20]  9,620  19,238
# backbond2.3.branch2.2.excite  [Conv2d]              [None, 480, 1, 1]          'weight', [480, 20, 1, 1]        'bias', [480]  10,080  20,158
# backbond2.3.branch2.2  [SqueezeExcite]              [None, 480, 14, 14]                                                   0  0
# backbond2.3.branch2.3.conv  [Conv2d]                [None, 80, 14, 14]         'weight', [80, 480, 1, 1]                  38,400  15,052,604
# backbond2.3.branch2.3.norm  [BatchNorm]             [None, 80, 14, 14]         'weight', [80]                   'bias', [80]  160  62,328
# backbond2.3.branch2.3  [Conv2d_Block]               [None, 80, 14, 14]                                                    0  0
# backbond2.3.branch2.4  [Dropout]                    [None, 80, 14, 14]                                                    0  0
# backbond2.3  [ShortCut2d]                           [None, 80, 14, 14]                                                    0  0
# backbond2.4.Identity  [Identity]                    [None, 80, 14, 14]                                                    0  0
# backbond2.4.branch2.0.conv  [Conv2d]                [None, 480, 14, 14]        'weight', [480, 80, 1, 1]                  38,400  15,052,604
# backbond2.4.branch2.0.norm  [BatchNorm]             [None, 480, 14, 14]        'weight', [480]                  'bias', [480]  960  375,928
# backbond2.4.branch2.0.activation  [Swish]           [None, 480, 14, 14]                                                   0  0
# backbond2.4.branch2.0  [Conv2d_Block]               [None, 480, 14, 14]                                                   0  0
# backbond2.4.branch2.1.conv  [DepthwiseConv2d]       [None, 480, 14, 14]        'weight', [480, 1, 3, 3]                   4,320  1,693,244
# backbond2.4.branch2.1.norm  [BatchNorm]             [None, 480, 14, 14]        'weight', [480]                  'bias', [480]  960  375,928
# backbond2.4.branch2.1.activation  [Swish]           [None, 480, 14, 14]                                                   0  0
# backbond2.4.branch2.1  [DepthwiseConv2d_Block]      [None, 480, 14, 14]                                                   0  0
# backbond2.4.branch2.2.pool  [GlobalAvgPool2d]       [None, 480]                                                           0  0
# backbond2.4.branch2.2.squeeze  [Conv2d]             [None, 20, 1, 1]           'weight', [20, 480, 1, 1]        'bias', [20]  9,620  19,238
# backbond2.4.branch2.2.excite  [Conv2d]              [None, 480, 1, 1]          'weight', [480, 20, 1, 1]        'bias', [480]  10,080  20,158
# backbond2.4.branch2.2  [SqueezeExcite]              [None, 480, 14, 14]                                                   0  0
# backbond2.4.branch2.3.conv  [Conv2d]                [None, 80, 14, 14]         'weight', [80, 480, 1, 1]                  38,400  15,052,604
# backbond2.4.branch2.3.norm  [BatchNorm]             [None, 80, 14, 14]         'weight', [80]                   'bias', [80]  160  62,328
# backbond2.4.branch2.3  [Conv2d_Block]               [None, 80, 14, 14]                                                    0  0
# backbond2.4.branch2.4  [Dropout]                    [None, 80, 14, 14]                                                    0  0
# backbond2.4  [ShortCut2d]                           [None, 80, 14, 14]                                                    0  0
# backbond2.5.0.conv  [Conv2d]                        [None, 480, 14, 14]        'weight', [480, 80, 1, 1]                  38,400  15,052,604
# backbond2.5.0.norm  [BatchNorm]                     [None, 480, 14, 14]        'weight', [480]                  'bias', [480]  960  375,928
# backbond2.5.0.activation  [Swish]                   [None, 480, 14, 14]                                                   0  0
# backbond2.5.0  [Conv2d_Block]                       [None, 480, 14, 14]                                                   0  0
# backbond2.5.1.conv  [DepthwiseConv2d]               [None, 480, 14, 14]        'weight', [480, 1, 5, 5]                   12,000  4,703,804
# backbond2.5.1.norm  [BatchNorm]                     [None, 480, 14, 14]        'weight', [480]                  'bias', [480]  960  375,928
# backbond2.5.1.activation  [Swish]                   [None, 480, 14, 14]                                                   0  0
# backbond2.5.1  [DepthwiseConv2d_Block]              [None, 480, 14, 14]                                                   0  0
# backbond2.5.2.pool  [GlobalAvgPool2d]               [None, 480]                                                           0  0
# backbond2.5.2.squeeze  [Conv2d]                     [None, 20, 1, 1]           'weight', [20, 480, 1, 1]        'bias', [20]  9,620  19,238
# backbond2.5.2.excite  [Conv2d]                      [None, 480, 1, 1]          'weight', [480, 20, 1, 1]        'bias', [480]  10,080  20,158
# backbond2.5.2  [SqueezeExcite]                      [None, 480, 14, 14]                                                   0  0
# backbond2.5.3.conv  [Conv2d]                        [None, 112, 14, 14]        'weight', [112, 480, 1, 1]                 53,760  21,073,724
# backbond2.5.3.norm  [BatchNorm]                     [None, 112, 14, 14]        'weight', [112]                  'bias', [112]  224  87,416
# backbond2.5.3  [Conv2d_Block]                       [None, 112, 14, 14]                                                   0  0
# backbond2.5.4  [Identity]                           [None, 112, 14, 14]                                                   0  0
# backbond2.6.Identity  [Identity]                    [None, 112, 14, 14]                                                   0  0
# backbond2.6.branch2.0.conv  [Conv2d]                [None, 672, 14, 14]        'weight', [672, 112, 1, 1]                 75,264  29,503,292
# backbond2.6.branch2.0.norm  [BatchNorm]             [None, 672, 14, 14]        'weight', [672]                  'bias', [672]  1,344  526,456
# backbond2.6.branch2.0.activation  [Swish]           [None, 672, 14, 14]                                                   0  0
# backbond2.6.branch2.0  [Conv2d_Block]               [None, 672, 14, 14]                                                   0  0
# backbond2.6.branch2.1.conv  [DepthwiseConv2d]       [None, 672, 14, 14]        'weight', [672, 1, 5, 5]                   16,800  6,585,404
# backbond2.6.branch2.1.norm  [BatchNorm]             [None, 672, 14, 14]        'weight', [672]                  'bias', [672]  1,344  526,456
# backbond2.6.branch2.1.activation  [Swish]           [None, 672, 14, 14]                                                   0  0
# backbond2.6.branch2.1  [DepthwiseConv2d_Block]      [None, 672, 14, 14]                                                   0  0
# backbond2.6.branch2.2.pool  [GlobalAvgPool2d]       [None, 672]                                                           0  0
# backbond2.6.branch2.2.squeeze  [Conv2d]             [None, 28, 1, 1]           'weight', [28, 672, 1, 1]        'bias', [28]  18,844  37,686
# backbond2.6.branch2.2.excite  [Conv2d]              [None, 672, 1, 1]          'weight', [672, 28, 1, 1]        'bias', [672]  19,488  38,974
# backbond2.6.branch2.2  [SqueezeExcite]              [None, 672, 14, 14]                                                   0  0
# backbond2.6.branch2.3.conv  [Conv2d]                [None, 112, 14, 14]        'weight', [112, 672, 1, 1]                 75,264  29,503,292
# backbond2.6.branch2.3.norm  [BatchNorm]             [None, 112, 14, 14]        'weight', [112]                  'bias', [112]  224  87,416
# backbond2.6.branch2.3  [Conv2d_Block]               [None, 112, 14, 14]                                                   0  0
# backbond2.6.branch2.4  [Dropout]                    [None, 112, 14, 14]                                                   0  0
# backbond2.6  [ShortCut2d]                           [None, 112, 14, 14]                                                   0  0
# backbond2.7.Identity  [Identity]                    [None, 112, 14, 14]                                                   0  0
# backbond2.7.branch2.0.conv  [Conv2d]                [None, 672, 14, 14]        'weight', [672, 112, 1, 1]                 75,264  29,503,292
# backbond2.7.branch2.0.norm  [BatchNorm]             [None, 672, 14, 14]        'weight', [672]                  'bias', [672]  1,344  526,456
# backbond2.7.branch2.0.activation  [Swish]           [None, 672, 14, 14]                                                   0  0
# backbond2.7.branch2.0  [Conv2d_Block]               [None, 672, 14, 14]                                                   0  0
# backbond2.7.branch2.1.conv  [DepthwiseConv2d]       [None, 672, 14, 14]        'weight', [672, 1, 5, 5]                   16,800  6,585,404
# backbond2.7.branch2.1.norm  [BatchNorm]             [None, 672, 14, 14]        'weight', [672]                  'bias', [672]  1,344  526,456
# backbond2.7.branch2.1.activation  [Swish]           [None, 672, 14, 14]                                                   0  0
# backbond2.7.branch2.1  [DepthwiseConv2d_Block]      [None, 672, 14, 14]                                                   0  0
# backbond2.7.branch2.2.pool  [GlobalAvgPool2d]       [None, 672]                                                           0  0
# backbond2.7.branch2.2.squeeze  [Conv2d]             [None, 28, 1, 1]           'weight', [28, 672, 1, 1]        'bias', [28]  18,844  37,686
# backbond2.7.branch2.2.excite  [Conv2d]              [None, 672, 1, 1]          'weight', [672, 28, 1, 1]        'bias', [672]  19,488  38,974
# backbond2.7.branch2.2  [SqueezeExcite]              [None, 672, 14, 14]                                                   0  0
# backbond2.7.branch2.3.conv  [Conv2d]                [None, 112, 14, 14]        'weight', [112, 672, 1, 1]                 75,264  29,503,292
# backbond2.7.branch2.3.norm  [BatchNorm]             [None, 112, 14, 14]        'weight', [112]                  'bias', [112]  224  87,416
# backbond2.7.branch2.3  [Conv2d_Block]               [None, 112, 14, 14]                                                   0  0
# backbond2.7.branch2.4  [Dropout]                    [None, 112, 14, 14]                                                   0  0
# backbond2.7  [ShortCut2d]                           [None, 112, 14, 14]                                                   0  0
# aspp.0.conv1.conv  [Conv2d]                         [None, 256, 14, 14]        'weight', [256, 112, 1, 1]                 28,672  11,239,228
# aspp.0.conv1.norm  [BatchNorm]                      [None, 256, 14, 14]        'weight', [256]                  'bias', [256]  512  200,312
# aspp.0.conv1  [Conv2d_Block]                        [None, 256, 14, 14]                                                   0  0
# aspp.0.aspp_dilation0.conv  [Conv2d]                [None, 256, 14, 14]        'weight', [256, 112, 3, 3]                 258,048  101,154,620
# aspp.0.aspp_dilation0.norm  [BatchNorm]             [None, 256, 14, 14]        'weight', [256]                  'bias', [256]  512  200,312
# aspp.0.aspp_dilation0  [Conv2d_Block]               [None, 256, 14, 14]                                                   0  0
# aspp.0.aspp_dilation1.conv  [Conv2d]                [None, 256, 14, 14]        'weight', [256, 112, 3, 3]                 258,048  101,154,620
# aspp.0.aspp_dilation1.norm  [BatchNorm]             [None, 256, 14, 14]        'weight', [256]                  'bias', [256]  512  200,312
# aspp.0.aspp_dilation1  [Conv2d_Block]               [None, 256, 14, 14]                                                   0  0
# aspp.0.aspp_dilation2.conv  [Conv2d]                [None, 256, 14, 14]        'weight', [256, 112, 3, 3]                 258,048  101,154,620
# aspp.0.aspp_dilation2.norm  [BatchNorm]             [None, 256, 14, 14]        'weight', [256]                  'bias', [256]  512  200,312
# aspp.0.aspp_dilation2  [Conv2d_Block]               [None, 256, 14, 14]                                                   0  0
# aspp.0.aspp_dilation3.conv  [Conv2d]                [None, 256, 14, 14]        'weight', [256, 112, 3, 3]                 258,048  101,154,620
# aspp.0.aspp_dilation3.norm  [BatchNorm]             [None, 256, 14, 14]        'weight', [256]                  'bias', [256]  512  200,312
# aspp.0.aspp_dilation3  [Conv2d_Block]               [None, 256, 14, 14]                                                   0  0
# aspp.0.aspp_pooling.0  [AdaptiveAvgPool2d]          [None, 112, 1, 1]                                                     0  0
# aspp.0.aspp_pooling.1  [Conv2d]                     [None, 256, 1, 1]          'weight', [256, 112, 1, 1]                 28,672  57,343
# aspp.0.aspp_pooling.2  [Upsampling2d]               [None, 256, 14, 14]                                                   0  0
# aspp.0  [ShortCut2d]                                [None, 1536, 14, 14]                                                  0  0
# aspp.1.conv  [Conv2d]                               [None, 256, 14, 14]        'weight', [256, 1536, 1, 1]                393,216  154,140,476
# aspp.1.norm  [BatchNorm]                            [None, 256, 14, 14]        'weight', [256]                  'bias', [256]  512  200,312
# aspp.1.activation  [Relu]                           [None, 256, 14, 14]                                                   0  0
# aspp.1  [Conv2d_Block]                              [None, 256, 14, 14]                                                   0  0
# low_level_conv.conv  [Conv2d]                       [None, 48, 56, 56]         'weight', [48, 24, 1, 1]                   1,152  7,222,208
# low_level_conv.norm  [BatchNorm]                    [None, 48, 56, 56]         'weight', [48]                   'bias', [48]  96  595,840
# low_level_conv.activation  [LeakyRelu]              [None, 48, 56, 56]                                                    0  0
# low_level_conv  [Conv2d_Block]                      [None, 48, 56, 56]                                                    0  0
# decoder.0.conv  [DepthwiseConv2d]                   [None, 152, 56, 56]        'weight', [152, 2, 3, 3]                   2,736  17,157,056
# decoder.0.norm  [BatchNorm]                         [None, 152, 56, 56]        'weight', [152]                  'bias', [152]  304  1,900,416
# decoder.0.activation  [LeakyRelu]                   [None, 152, 56, 56]                                                   0  0
# decoder.0  [DepthwiseConv2d_Block]                  [None, 152, 56, 56]                                                   0  0
# decoder.1.conv  [DepthwiseConv2d]                   [None, 152, 56, 56]        'weight', [152, 1, 3, 3]                   1,368  8,576,960
# decoder.1.norm  [BatchNorm]                         [None, 152, 56, 56]        'weight', [152]                  'bias', [152]  304  1,900,416
# decoder.1.activation  [LeakyRelu]                   [None, 152, 56, 56]                                                   0  0
# decoder.1  [DepthwiseConv2d_Block]                  [None, 152, 56, 56]                                                   0  0
# decoder.2  [Conv2d]                                 [None, 2, 56, 56]          'weight', [2, 152, 1, 1]                   304  1,903,552
# decoder.3  [SoftMax]                                [None, 2, 56, 56]                                                     0  0
# ================================================================
# Total params: 2,343,896
# Trainable params: 1,492,088
# Non-trainable params: 851,808
# Total MACC: 560,705,216
# Total FLOPs: 1.12114 GFLOPs
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 245.47
# Params size (MB): 8.94
# Estimated Total Size (MB): 254.98
# ----------------------------------------------------------------
# ImageSegmentationModel(
#   (_losses): <trident.optims.pytorch_losses.DiceLoss object at 0x000002439816ACA0>
#   (_losses): <trident.optims.pytorch_losses.CrossEntropyLoss object at 0x000002439816AE50>
#   (_losses): <trident.optims.pytorch_losses.IoULoss object at 0x000002439816A1F0>
#   (_losses): <trident.optims.pytorch_losses.FocalLoss object at 0x000002439816A520>
#   (_metrics): <function pixel_accuracy at 0x00000243B1295B80>
#   (_metrics): <function iou at 0x00000243B1295DC0>
#   (loss_weights): 1.0
#   (loss_weights): 4.0
#   (loss_weights): 0.5
#   (loss_weights): 1.0
#   (_regs): <function l2_reg at 0x00000243B0D78820>
#   (_constraints): functools.partial(<function min_max_norm at 0x00000243B0D78670>)
# )

# %%
plan=TrainingPlan()\
    .add_training_item(deeplabv3,name='deeplab')\
    .with_data_loader(data_provider)\
    .repeat_epochs(20)\
    .with_batch_size(16)\
    .print_progress_scheduling(20,unit='batch')\
    .display_loss_metric_curve_scheduling(frequency=100,unit='batch',imshow=True)\
    .save_model_scheduling(20,unit='batch')\
    #.with_tensorboard()\

#add_training_item加入要訓練的模型
#with_data_loader加入數據提供者
#repeat_epochs設定要執行的epoch數量
#within_minibatch_size設定minibatch_size
#print_progress_scheduling設定列印進度的頻率
#display_loss_metric_curve_scheduling設定顯示損失函數曲線的頻率
#save_model_scheduling設定存檔的頻率

# %%
plan.start_now()
# Out:
# deeplab     Step: 881ms    | Loss: -4.01 | pixel_accuracy: 83.556% , iou: 77.741%  | lr: 1.000e-08  | epoch: 19  ( 320/357 )
# deeplab     Step: 825ms    | Loss: -3.86 | pixel_accuracy: 82.135% , iou: 60.273%  | lr: 1.000e-08  | epoch: 19  ( 340/357 )
