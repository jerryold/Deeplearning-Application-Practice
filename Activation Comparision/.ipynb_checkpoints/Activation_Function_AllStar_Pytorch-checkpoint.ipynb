# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from IPython import display

from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D

plt.rcParams.update({'font.size': 10})#指定字體大小

# matplotlib.rcParams[‘figure.figsize’]#图片像素
# matplotlib.rcParams[‘savefig.dpi’]#分辨率
# plt.savefig(‘plot123_2.png’, dpi=200)#指定分辨率
# Out:
# C:\Users\jerryold\anaconda3\envs\test2\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\jerryold\anaconda3\envs\test2\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
# C:\Users\jerryold\anaconda3\envs\test2\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   stacklevel=1)

# %% [markdown]
# # 活化函數大清點 (pytorch)

# %% [markdown]
# 支援python 版本: 3.5以上
# 支援pytorch: 1.4以上

# %% [raw]
# 這個實作是關於活化函數的理解。在神經元的底層結構中，活化函數扮演著將收到的信號賦予非線性特性的關鍵角色，也因此活化函數雖然不是太顯眼，但是仍有不少研究者推出新的活化函數希望可以藉由活化函數來提升模型效度。

# %%
import gc
import glob
import os
import time
import cv2
os.environ['TRIDENT_BACKEND'] = 'pytorch'
# !pip install tridentx --upgrade
import trident as T
from trident import *
from trident.layers.pytorch_activations import __all__
# Out:
# Collecting trident
#   Using cached trident-1.2.3-py2.py3-none-any.whl (229 kB)
# Collecting yt-astro-analysis
#   Using cached yt_astro_analysis-1.0.0.tar.gz (1.5 MB)
# Collecting trident
#   Using cached trident-1.2.2-py2.py3-none-any.whl (229 kB)
#   Using cached trident-1.2.1-py2.py3-none-any.whl (229 kB)
#   Using cached trident-1.2-py2.py3-none-any.whl (229 kB)
#   Using cached trident-1.1-py2.py3-none-any.whl (222 kB)
# Requirement already satisfied: matplotlib in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from trident) (3.4.3)
# Requirement already satisfied: numpy in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from trident) (1.21.2)
# Requirement already satisfied: setuptools in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from trident) (57.4.0)
# Collecting astropy
#   Downloading astropy-4.3.1-cp37-cp37m-win_amd64.whl (6.4 MB)
# Collecting future
#   Using cached future-0.18.2.tar.gz (829 kB)
# Collecting yt>=3.4.0
#   Downloading yt-4.0.1-cp37-cp37m-win_amd64.whl (17.9 MB)
# Requirement already satisfied: h5py in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from trident) (3.3.0)
# Requirement already satisfied: requests in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from trident) (2.26.0)
# Collecting sympy>=1.2
#   Using cached sympy-1.8-py3-none-any.whl (6.1 MB)
# Collecting toml>=0.10.2
#   Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: pyyaml>=4.2b1 in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from yt>=3.4.0->trident) (5.4.1)
# Collecting more-itertools>=8.4
#   Using cached more_itertools-8.8.0-py3-none-any.whl (48 kB)
# Collecting unyt>=2.8.0
#   Using cached unyt-2.8.0-py2.py3-none-any.whl (98 kB)
# Requirement already satisfied: iPython>=1.0 in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from yt>=3.4.0->trident) (7.26.0)
# Requirement already satisfied: tqdm>=3.4.0 in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from yt>=3.4.0->trident) (4.62.2)
# Requirement already satisfied: packaging>=20.9 in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from yt>=3.4.0->trident) (21.0)
# Requirement already satisfied: pygments in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from iPython>=1.0->yt>=3.4.0->trident) (2.10.0)
# Requirement already satisfied: colorama in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from iPython>=1.0->yt>=3.4.0->trident) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from iPython>=1.0->yt>=3.4.0->trident) (3.0.20)
# Requirement already satisfied: matplotlib-inline in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from iPython>=1.0->yt>=3.4.0->trident) (0.1.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from iPython>=1.0->yt>=3.4.0->trident) (0.18.0)
# Requirement already satisfied: backcall in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from iPython>=1.0->yt>=3.4.0->trident) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from iPython>=1.0->yt>=3.4.0->trident) (5.0.5)
# Requirement already satisfied: pickleshare in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from iPython>=1.0->yt>=3.4.0->trident) (0.7.5)
# Requirement already satisfied: decorator in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from iPython>=1.0->yt>=3.4.0->trident) (5.0.9)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from jedi>=0.16->iPython>=1.0->yt>=3.4.0->trident) (0.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from matplotlib->trident) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from matplotlib->trident) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from matplotlib->trident) (8.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from matplotlib->trident) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from matplotlib->trident) (2.4.7)
# Requirement already satisfied: six in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from cycler>=0.10->matplotlib->trident) (1.15.0)
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\jerryold\anaconda3\envs\test2\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jerryold\\AppData\\Local\\Temp\\pip-install-jjp1g4me\\yt-astro-analysis_506dd36eb51a4b1283bb0190e0f367ef\\setup.py'"'"'; __file__='"'"'C:\\Users\\jerryold\\AppData\\Local\\Temp\\pip-install-jjp1g4me\\yt-astro-analysis_506dd36eb51a4b1283bb0190e0f367ef\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\jerryold\AppData\Local\Temp\pip-pip-egg-info-4_f2m552'
#          cwd: C:\Users\jerryold\AppData\Local\Temp\pip-install-jjp1g4me\yt-astro-analysis_506dd36eb51a4b1283bb0190e0f367ef\
#     Complete output (47 lines):
#     test_openmp.c
#     正在產生程式碼
#     已完成程式碼產生
#     Using OpenMP to compile parallel extensions
#     Traceback (most recent call last):
#       File "C:\Users\jerryold\anaconda3\envs\test2\lib\site-packages\pkg_resources\__init__.py", line 3016, in _dep_map
#         return self.__dep_map
#       File "C:\Users\jerryold\anaconda3\envs\test2\lib\site-packages\pkg_resources\__init__.py", line 2813, in __getattr__
#         raise AttributeError(attr)
#     AttributeError: _DistInfoDistribution__dep_map
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "C:\Users\jerryold\anaconda3\envs\test2\lib\site-packages\pkg_resources\__init__.py", line 3007, in _parsed_pkg_info
#         return self._pkg_info
#       File "C:\Users\jerryold\anaconda3\envs\test2\lib\site-packages\pkg_resources\__init__.py", line 2813, in __getattr__
#         raise AttributeError(attr)
#     AttributeError: _pkg_info
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\jerryold\AppData\Local\Temp\pip-install-jjp1g4me\yt-astro-analysis_506dd36eb51a4b1283bb0190e0f367ef\setup.py", line 178, in <module>
#         ext_modules=cython_extensions + extensions,
#       File "C:\Users\jerryold\anaconda3\envs\test2\lib\site-packages\setuptools\__init__.py", line 152, in setup
#         _install_setup_requires(attrs)
#       File "C:\Users\jerryold\anaconda3\envs\test2\lib\site-packages\setuptools\__init__.py", line 147, in _install_setup_requires
#         dist.fetch_build_eggs(dist.setup_requires)
#       File "C:\Users\jerryold\anaconda3\envs\test2\lib\site-packages\setuptools\dist.py", line 788, in fetch_build_eggs
#         replace_conflicting=True,
#       File "C:\Users\jerryold\anaconda3\envs\test2\lib\site-packages\pkg_resources\__init__.py", line 780, in resolve
#         new_requirements = dist.requires(req.extras)[::-1]
#       File "C:\Users\jerryold\anaconda3\envs\test2\lib\site-packages\pkg_resources\__init__.py", line 2734, in requires
#         dm = self._dep_map
#       File "C:\Users\jerryold\anaconda3\envs\test2\lib\site-packages\pkg_resources\__init__.py", line 3018, in _dep_map
#         self.__dep_map = self._compute_dependencies()
#       File "C:\Users\jerryold\anaconda3\envs\test2\lib\site-packages\pkg_resources\__init__.py", line 3027, in _compute_dependencies
#         for req in self._parsed_pkg_info.get_all('Requires-Dist') or []:
#       File "C:\Users\jerryold\anaconda3\envs\test2\lib\site-packages\pkg_resources\__init__.py", line 3009, in _parsed_pkg_info
#         metadata = self.get_metadata(self.PKG_INFO)
#       File "C:\Users\jerryold\anaconda3\envs\test2\lib\site-packages\pkg_resources\__init__.py", line 1407, in get_metadata
#         value = self._get(path)
#       File "C:\Users\jerryold\anaconda3\envs\test2\lib\site-packages\pkg_resources\__init__.py", line 1611, in _get
#         with open(path, 'rb') as stream:
#     FileNotFoundError: [Errno 2] No such file or directory: 'c:\\users\\jerryold\\anaconda3\\envs\\test2\\lib\\site-packages\\numpy-1.21.2.dist-info\\METADATA'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/88/56/c5726edd3ff2ddba40c79a53d05e3602fe4377d595836b89ab33182cd47c/yt_astro_analysis-1.0.0.tar.gz#sha256=f37cd0fa7c4db58b7e577adc7c42e6f7c7f9cd1fadf62db368a3b51171c6f694 (from https://pypi.org/simple/yt-astro-analysis/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'c:\\users\\jerryold\\anaconda3\\envs\\test2\\lib\\site-packages\\numpy-1.21.2.dist-info\\METADATA'

# %% [raw]
# 在我這次為課程封裝的 API trident 中，只需要利用get_activation('活化函數名稱')即可回傳對應的活化函數，我們可以利用它結合Matplotlib 來繪製值域以及一階導數分布圖。

# %%
fig = plt.figure(figsize=(16, 16))
plt.ion()
plt.subplots_adjust(wspace=0.4, hspace=0.6)
n = 1
items = __all__[:-1]  # 取得活化函數名稱清單

for k in items:
    if k not in ('PRelu','CRelu'):
        try:
            act_fn = get_activation(k)
            x = np.arange(-10, 10, 0.1).astype(np.float32) # 產生從-10到10之間，每隔0.1一筆的向量(x)
            tensor_x = expand_dims(to_tensor(x),0)  # 向量轉tensor
            y = to_numpy(act_fn(tensor_x))[0]  # 計算向量經過活化函數的結果(y)
            ax1 = fig.add_subplot(7, 4, n)  # 宣告7*4個子圖
            ax1.plot(x, y)  # 將x,y繪製圖表
            ax1.plot(x[1:], np.diff(y) / (np.diff(x) + 1e-8), ls=':')  # np.diff在計算隔一筆的差異。將y的微小變化除以x的微小變化就是梯度
            ax1.set_title(k)

        except Exception as e:
            print(e)
            pass
        n += 1
display.display(fig)  # 將圖表顯示在notebook上
plt.close(fig)  # 把figure關閉，免得出現一堆關不掉的窗口

# %% [markdown]
# 接下來我們想要評測一下幾個傳統活化函數與新的活化函數之間的效能差異，我們將從幾點來評估它:
# 1.  計算時長(表示計算的開銷)
# 2. 跑 mnist 1000 minibatch 的訓練階段最佳accuracy以及最後10個批次的accuracy
# 3. 使用一樣的數據進行推論
# 4. 使用加入大量噪聲的數據進行推論(確認跑出來模型的通用性)
# 5. 檢視訓練過程的梯度與權重分布
# 6. 梯度為零比率

# %% [markdown]
# 下面的語法是使用trident API 讀取mnist數據集
# 你也可以換成T.load_mnist('fashion-mnist')來改讀取fashion mnist

# %%
data_provider=T.load_mnist('fashion-mnist')   #取得fashion-mnist數據集

im,label=data_provider.next() #調用一次以獲取一個minibatch的數據與標籤
print(im.shape)
im=array2image(np.concatenate(im[:8],axis=2)).resize((64*8,64))
#取8筆，把形狀reshapet成(8,28,28)且反正規化，並且沿著寬的方向(axis=1)疊合，並且把圖片尺寸放大到(64*8,64)

data_provider.image_transform_funcs=[Normalize(127.5,127.5)]  #利用減127.5除以127.5的方式來正規化圖片向量(值域會落在正負1之間)
im
# Out:
# archive file is already existing, donnot need download again.
# archive file is already existing, donnot need download again.
# Mapping class_names  in en-US   success, total 10 class names added.
# (8, 1, 28, 28)
# <PIL.Image.Image image mode=L size=512x64 at 0x2A1678209C8>

# %% [markdown]
# 若是要產生加入高度噪聲的數據，只需要在noise_dataset.image_transform_funcs中多加入個add_noise(intensity=0.3)，表示會加入30% 強度的隨機噪音，我們將它產生的數據輸出看一下，會是如下圖的結果，使用他的目的在於用乾淨的數據訓練，看看它第一次遇到那麼髒的數據的效度會有多大的程度衰退。

# %%
noise_data_provider=T.load_mnist('fashion-mnist')#取得mnist數據集
noise_data_provider.image_transform_funcs=[AddNoise(intensity=0.3)]
noise_im,noise_label=noise_data_provider.next() #調用一次以獲取一個minibatch的數據與標籤
print(noise_im.shape)
noise_im=array2image(np.concatenate(noise_im[:8],axis=2)).resize((64*8,64))
#取8筆，把形狀reshapet成(8,28,28)且反正規化，並且沿著寬的方向(axis=1)疊合，並且把圖片尺寸放大到(64*8,64)
noise_data_provider.image_transform_funcs=[AddNoise(intensity=0.3),Normalize(127.5,127.5)]#除了正規化之外`,，額外添加30%噪音    
noise_im
# Out:
# archive file is already existing, donnot need download again.
# archive file is already existing, donnot need download again.
# Mapping class_names  in en-US   success, total 10 class names added.
# (8, 1, 28, 28)
# <PIL.Image.Image image mode=L size=512x64 at 0x2A151CF3FC8>

# %% [markdown]
# 我們這次選擇測試用的活化函數包括了較為傳統的relu, leaky_relu，tanh以及sigmoid，同時也比較了幾個新生代的活化函數，包括了selu,swish,mish以及bert版的gelu。

# %%
activations=['relu','leaky_relu','sigmoid','tanh','selu','swish','mish','gelu','SIREN']
performance_dict=OrderedDict()

# %% [markdown]
# 接下來就把要測試的目標包裝成測試函數

# %%
def test_activity_function(act):
    performance_dict[act]=OrderedDict()
    #清掉記憶體垃圾以避免影響效能
    gc.collect()
    act_func=get_activation(act)
    print(act)
    
    #計算跑 10 萬次的總時間
    data =to_tensor(np.random.standard_normal((100000,1))) 
    start = time.time()
    results=[act_func(data[i]) for  i  in range(100000)]
    sec = time.time() - start
    print('{0:.6f} sec'.format(sec))
    performance_dict[act]['跑 10 萬次的總時間']=sec

    #建 mnist模
    net=Sequential(
    Flatten(),
    Dense(128,use_bias=False,activation=act),
    Dense(64,use_bias=False,activation=act),
    Dense(10,use_bias=False,activation=None),
    SoftMax())
    
    model=Model(input_shape=(1,28,28),output=net)\
    .with_optimizer(optimizer='SGD',lr=1e-3)\
    .with_loss(CrossEntropyLoss)\
    .with_metric(accuracy)
    
    plan=TrainingPlan()\
    .add_training_item(model)\
    .with_data_loader(data_provider)\
    .with_batch_size(128)\
    .print_progress_scheduling(100,unit='batch')\

    #讓他跑1000 次，過程中的權重變化與梯度變化都保留
    plan.only_steps(num_steps=1000,collect_data_inteval=10,keep_weights_history=True,keep_gradient_history=True )
    
    loss_indexs,loss_values=model.training_context['losses'].get_series('total_losses')
    accuracy_indexs,accuracy_values=model.training_context['metrics'].get_series('accuracy')
    print('最低 loss {0:.4e}  最佳 metrics {1:.4%}  最後10次 metrics {2:.4%}'.format(np.array(loss_values).min(),
                                                                              np.array(accuracy_values).max(),
                                                                              np.array(accuracy_values)[-10:].mean()))
    performance_dict[act]['最佳 metrics'] =np.array(accuracy_values).max()
    performance_dict[act]['最後10次 metrics'] =np.array(accuracy_values)[-10:].mean()
    
    
    # 分別使用乾淨數據與噪聲數據進行推論
    net.eval()
    accuracys=[]
    for i in range(100):
        input,target=data_provider.next()
        input,target=to_tensor(input),to_tensor(target)
        accuracys.append(to_numpy(accuracy(net(input),target)))
    accuracys=np.asarray(accuracys)
        
    print('正常樣本 accuracy {0:.4%}  DIFF: {1:.4%} '.format(accuracys.mean(),accuracys.mean()-performance_dict[act]['最後10次 metrics']))
    performance_dict[act]['正常樣本 accuracy DIFF']=accuracys.mean()-performance_dict[act]['最後10次 metrics']
    
    
    noise_accuracys=[]
    for i in range(100):
        input,target=noise_data_provider.next()
        input,target=to_tensor(input),to_tensor(target)
        noise_accuracys.append(to_numpy(accuracy(net(input),target)))
    noise_accuracys=np.asarray(noise_accuracys)
        
    print('噪聲樣本 accuracy {0:.4%}  DIFF: {1:.4%} '.format(noise_accuracys.mean(),noise_accuracys.mean()-performance_dict[act]['最後10次 metrics']))
    performance_dict[act]['噪聲樣本 accuracy DIFF']=noise_accuracys.mean()-performance_dict[act]['最後10次 metrics']
    
    #繪製梯度與權重分布
    weights_history=plan.training_items[0].weights_history
    gradients_history=plan.training_items[0].gradients_history
    
    grads=[]
    weights=[]
    for i in range(len(gradients_history)):
        grads.append(gradients_history[i].value_list[0].reshape([-1]))

    for i in range(len(weights_history)):
         weights.append(weights_history[i].value_list[0].reshape([-1]))
    
    grads=np.asarray(grads)
    
    weights=np.asarray(weights)

# %%
test_activity_function('relu')
# Out:
# relu
# 1.258217 sec
# CrossEntropyLoss( output: Tensor[(None,)] , target: Tensor[(None,)] ) -> loss: Tensor[(None,)]
# accuracy( output: Tensor[(None,)] , target: Tensor[(None,)] , topk: int =1, axis: int =1, ignore_index: int =-100, exclude_mask: bool =False) -> output: Tensor[(None,)]
# data_feed for model 0 :
# {
#     "axis": "axis",
#     "exclude_mask": "exclude_mask",
#     "ignore_index": "ignore_index",
#     "output": "output",
#     "target": "label",
#     "topk": "topk",
#     "x": "image"
# }
# { CrossEntropyLoss: 2.32, total_losses: 2.32 }
# model 0     Step: 7ms      | Loss: 2.3 | accuracy: 13.281%  | lr: 1.000e-03  | epoch: 0  ( 100/1000 )
# model 0     Step: 6ms      | Loss: 2.28 | accuracy: 18.359%  | lr: 1.000e-03  | epoch: 0  ( 200/1000 )
# model 0     Step: 5ms      | Loss: 2.26 | accuracy: 25.521%  | lr: 1.000e-03  | epoch: 0  ( 300/1000 )
# model 0     Step: 6ms      | Loss: 2.24 | accuracy: 26.367%  | lr: 1.000e-03  | epoch: 0  ( 400/1000 )
# model 0     Step: 6ms      | Loss: 2.21 | accuracy: 28.125%  | lr: 1.000e-03  | epoch: 0  ( 500/1000 )
# model 0     Step: 6ms      | Loss: 2.18 | accuracy: 30.078%  | lr: 1.000e-03  | epoch: 0  ( 600/1000 )
# model 0     Step: 7ms      | Loss: 2.14 | accuracy: 31.920%  | lr: 1.000e-03  | epoch: 0  ( 700/1000 )
# model 0     Step: 6ms      | Loss: 2.1 | accuracy: 33.789%  | lr: 1.000e-03  | epoch: 0  ( 800/1000 )
# model 0     Step: 6ms      | Loss: 2.06 | accuracy: 34.462%  | lr: 1.000e-03  | epoch: 0  ( 900/1000 )
# 最低 loss 1.9790e+00  最佳 metrics 46.8750%  最後10次 metrics 34.4618%
# 正常樣本 accuracy 44.2656%  DIFF: 9.8038%
# 噪聲樣本 accuracy 45.0000%  DIFF: 10.5382%

# %%
test_activity_function('leaky_relu')
# Out:
# leaky_relu
# 1.305685 sec
# CrossEntropyLoss( output: Tensor[(None,)] , target: Tensor[(None,)] ) -> loss: Tensor[(None,)]
# accuracy( output: Tensor[(None,)] , target: Tensor[(None,)] , topk: int =1, axis: int =1, ignore_index: int =-100, exclude_mask: bool =False) -> output: Tensor[(None,)]
# data_feed for model 0 :
# {
#     "axis": "axis",
#     "exclude_mask": "exclude_mask",
#     "ignore_index": "ignore_index",
#     "output": "output",
#     "target": "label",
#     "topk": "topk",
#     "x": "image"
# }
# { CrossEntropyLoss: 2.32, total_losses: 2.32 }
# model 0     Step: 6ms      | Loss: 2.29 | accuracy: 17.969%  | lr: 1.000e-03  | epoch: 0  ( 100/1000 )
# model 0     Step: 6ms      | Loss: 2.24 | accuracy: 25.391%  | lr: 1.000e-03  | epoch: 0  ( 200/1000 )
# model 0     Step: 6ms      | Loss: 2.2 | accuracy: 27.865%  | lr: 1.000e-03  | epoch: 0  ( 300/1000 )
# model 0     Step: 6ms      | Loss: 2.17 | accuracy: 29.297%  | lr: 1.000e-03  | epoch: 0  ( 400/1000 )
# model 0     Step: 6ms      | Loss: 2.11 | accuracy: 30.781%  | lr: 1.000e-03  | epoch: 0  ( 500/1000 )
# model 0     Step: 6ms      | Loss: 2.07 | accuracy: 31.380%  | lr: 1.000e-03  | epoch: 0  ( 600/1000 )
# model 0     Step: 6ms      | Loss: 2.01 | accuracy: 31.250%  | lr: 1.000e-03  | epoch: 0  ( 700/1000 )
# model 0     Step: 6ms      | Loss: 1.93 | accuracy: 32.324%  | lr: 1.000e-03  | epoch: 0  ( 800/1000 )
# model 0     Step: 6ms      | Loss: 1.87 | accuracy: 33.247%  | lr: 1.000e-03  | epoch: 0  ( 900/1000 )
# 最低 loss 1.7417e+00  最佳 metrics 40.6250%  最後10次 metrics 33.2465%
# 正常樣本 accuracy 40.2656%  DIFF: 7.0191%
# 噪聲樣本 accuracy 39.8750%  DIFF: 6.6285%

# %%
test_activity_function('sigmoid')
# Out:
# sigmoid
# 1.240814 sec
# CrossEntropyLoss( output: Tensor[(None,)] , target: Tensor[(None,)] ) -> loss: Tensor[(None,)]
# accuracy( output: Tensor[(None,)] , target: Tensor[(None,)] , topk: int =1, axis: int =1, ignore_index: int =-100, exclude_mask: bool =False) -> output: Tensor[(None,)]
# data_feed for model 0 :
# {
#     "axis": "axis",
#     "exclude_mask": "exclude_mask",
#     "ignore_index": "ignore_index",
#     "output": "output",
#     "target": "label",
#     "topk": "topk",
#     "x": "image"
# }
# { CrossEntropyLoss: 2.3, total_losses: 2.3 }
# model 0     Step: 5ms      | Loss: 2.32 | accuracy: 7.812%  | lr: 1.000e-03  | epoch: 0  ( 100/1000 )
# model 0     Step: 6ms      | Loss: 2.32 | accuracy: 8.984%  | lr: 1.000e-03  | epoch: 0  ( 200/1000 )
# model 0     Step: 5ms      | Loss: 2.31 | accuracy: 9.896%  | lr: 1.000e-03  | epoch: 0  ( 300/1000 )
# model 0     Step: 5ms      | Loss: 2.31 | accuracy: 9.570%  | lr: 1.000e-03  | epoch: 0  ( 400/1000 )
# model 0     Step: 6ms      | Loss: 2.31 | accuracy: 9.844%  | lr: 1.000e-03  | epoch: 0  ( 500/1000 )
# model 0     Step: 6ms      | Loss: 2.3 | accuracy: 9.766%  | lr: 1.000e-03  | epoch: 0  ( 600/1000 )
# model 0     Step: 6ms      | Loss: 2.31 | accuracy: 10.156%  | lr: 1.000e-03  | epoch: 0  ( 700/1000 )
# model 0     Step: 6ms      | Loss: 2.3 | accuracy: 10.938%  | lr: 1.000e-03  | epoch: 0  ( 800/1000 )
# model 0     Step: 6ms      | Loss: 2.3 | accuracy: 11.719%  | lr: 1.000e-03  | epoch: 0  ( 900/1000 )
# 最低 loss 2.2612e+00  最佳 metrics 17.9688%  最後10次 metrics 11.7188%
# 正常樣本 accuracy 19.4844%  DIFF: 7.7656%
# 噪聲樣本 accuracy 17.7500%  DIFF: 6.0312%

# %%
test_activity_function('tanh')
# Out:
# tanh
# 1.420911 sec
# CrossEntropyLoss( output: Tensor[(None,)] , target: Tensor[(None,)] ) -> loss: Tensor[(None,)]
# accuracy( output: Tensor[(None,)] , target: Tensor[(None,)] , topk: int =1, axis: int =1, ignore_index: int =-100, exclude_mask: bool =False) -> output: Tensor[(None,)]
# data_feed for model 0 :
# {
#     "axis": "axis",
#     "exclude_mask": "exclude_mask",
#     "ignore_index": "ignore_index",
#     "output": "output",
#     "target": "label",
#     "topk": "topk",
#     "x": "image"
# }
# { CrossEntropyLoss: 2.28, total_losses: 2.28 }
# model 0     Step: 5ms      | Loss: 2.21 | accuracy: 18.750%  | lr: 1.000e-03  | epoch: 0  ( 100/1000 )
# model 0     Step: 5ms      | Loss: 2.13 | accuracy: 22.266%  | lr: 1.000e-03  | epoch: 0  ( 200/1000 )
# model 0     Step: 5ms      | Loss: 2.06 | accuracy: 25.000%  | lr: 1.000e-03  | epoch: 0  ( 300/1000 )
# model 0     Step: 6ms      | Loss: 2.01 | accuracy: 31.055%  | lr: 1.000e-03  | epoch: 0  ( 400/1000 )
# model 0     Step: 5ms      | Loss: 1.93 | accuracy: 32.812%  | lr: 1.000e-03  | epoch: 0  ( 500/1000 )
# model 0     Step: 5ms      | Loss: 1.87 | accuracy: 35.938%  | lr: 1.000e-03  | epoch: 0  ( 600/1000 )
# model 0     Step: 5ms      | Loss: 1.81 | accuracy: 38.728%  | lr: 1.000e-03  | epoch: 0  ( 700/1000 )
# model 0     Step: 6ms      | Loss: 1.75 | accuracy: 39.355%  | lr: 1.000e-03  | epoch: 0  ( 800/1000 )
# model 0     Step: 6ms      | Loss: 1.71 | accuracy: 40.799%  | lr: 1.000e-03  | epoch: 0  ( 900/1000 )
# 最低 loss 1.6187e+00  最佳 metrics 55.4688%  最後10次 metrics 40.7986%
# 正常樣本 accuracy 57.2656%  DIFF: 16.4670%
# 噪聲樣本 accuracy 58.1250%  DIFF: 17.3264%

# %%
test_activity_function('selu')
# Out:
# selu
# 1.475185 sec
# CrossEntropyLoss( output: Tensor[(None,)] , target: Tensor[(None,)] ) -> loss: Tensor[(None,)]
# accuracy( output: Tensor[(None,)] , target: Tensor[(None,)] , topk: int =1, axis: int =1, ignore_index: int =-100, exclude_mask: bool =False) -> output: Tensor[(None,)]
# data_feed for model 0 :
# {
#     "axis": "axis",
#     "exclude_mask": "exclude_mask",
#     "ignore_index": "ignore_index",
#     "output": "output",
#     "target": "label",
#     "topk": "topk",
#     "x": "image"
# }
# { CrossEntropyLoss: 2.35, total_losses: 2.35 }
# model 0     Step: 7ms      | Loss: 2.07 | accuracy: 36.719%  | lr: 1.000e-03  | epoch: 0  ( 100/1000 )
# model 0     Step: 6ms      | Loss: 1.86 | accuracy: 45.312%  | lr: 1.000e-03  | epoch: 0  ( 200/1000 )
# model 0     Step: 6ms      | Loss: 1.69 | accuracy: 50.521%  | lr: 1.000e-03  | epoch: 0  ( 300/1000 )
# model 0     Step: 6ms      | Loss: 1.56 | accuracy: 52.734%  | lr: 1.000e-03  | epoch: 0  ( 400/1000 )
# model 0     Step: 6ms      | Loss: 1.43 | accuracy: 54.219%  | lr: 1.000e-03  | epoch: 0  ( 500/1000 )
# model 0     Step: 6ms      | Loss: 1.36 | accuracy: 55.729%  | lr: 1.000e-03  | epoch: 0  ( 600/1000 )
# model 0     Step: 6ms      | Loss: 1.31 | accuracy: 57.478%  | lr: 1.000e-03  | epoch: 0  ( 700/1000 )
# model 0     Step: 6ms      | Loss: 1.19 | accuracy: 58.203%  | lr: 1.000e-03  | epoch: 0  ( 800/1000 )
# model 0     Step: 6ms      | Loss: 1.16 | accuracy: 60.156%  | lr: 1.000e-03  | epoch: 0  ( 900/1000 )
# 最低 loss 9.5856e-01  最佳 metrics 75.7812%  最後10次 metrics 60.1562%
# 正常樣本 accuracy 70.2187%  DIFF: 10.0625%
# 噪聲樣本 accuracy 72.2500%  DIFF: 12.0938%

# %%
test_activity_function('swish')
# Out:
# swish
# 2.012923 sec
# CrossEntropyLoss( output: Tensor[(None,)] , target: Tensor[(None,)] ) -> loss: Tensor[(None,)]
# accuracy( output: Tensor[(None,)] , target: Tensor[(None,)] , topk: int =1, axis: int =1, ignore_index: int =-100, exclude_mask: bool =False) -> output: Tensor[(None,)]
# data_feed for model 0 :
# {
#     "axis": "axis",
#     "exclude_mask": "exclude_mask",
#     "ignore_index": "ignore_index",
#     "output": "output",
#     "target": "label",
#     "topk": "topk",
#     "x": "image"
# }
# { CrossEntropyLoss: 2.31, total_losses: 2.31 }
# model 0     Step: 6ms      | Loss: 2.3 | accuracy: 15.625%  | lr: 1.000e-03  | epoch: 0  ( 100/1000 )
# model 0     Step: 6ms      | Loss: 2.29 | accuracy: 20.703%  | lr: 1.000e-03  | epoch: 0  ( 200/1000 )
# model 0     Step: 6ms      | Loss: 2.28 | accuracy: 22.917%  | lr: 1.000e-03  | epoch: 0  ( 300/1000 )
# model 0     Step: 6ms      | Loss: 2.27 | accuracy: 24.219%  | lr: 1.000e-03  | epoch: 0  ( 400/1000 )
# model 0     Step: 6ms      | Loss: 2.25 | accuracy: 26.406%  | lr: 1.000e-03  | epoch: 0  ( 500/1000 )
# model 0     Step: 6ms      | Loss: 2.24 | accuracy: 27.995%  | lr: 1.000e-03  | epoch: 0  ( 600/1000 )
# model 0     Step: 6ms      | Loss: 2.23 | accuracy: 29.241%  | lr: 1.000e-03  | epoch: 0  ( 700/1000 )
# model 0     Step: 6ms      | Loss: 2.21 | accuracy: 31.152%  | lr: 1.000e-03  | epoch: 0  ( 800/1000 )
# model 0     Step: 6ms      | Loss: 2.19 | accuracy: 32.378%  | lr: 1.000e-03  | epoch: 0  ( 900/1000 )
# 最低 loss 2.1466e+00  最佳 metrics 44.5312%  最後10次 metrics 32.3785%
# 正常樣本 accuracy 41.7109%  DIFF: 9.3325%
# 噪聲樣本 accuracy 42.6250%  DIFF: 10.2465%

# %%
test_activity_function('mish')
# Out:
# mish
# 1.819236 sec
# CrossEntropyLoss( output: Tensor[(None,)] , target: Tensor[(None,)] ) -> loss: Tensor[(None,)]
# accuracy( output: Tensor[(None,)] , target: Tensor[(None,)] , topk: int =1, axis: int =1, ignore_index: int =-100, exclude_mask: bool =False) -> output: Tensor[(None,)]
# data_feed for model 0 :
# {
#     "axis": "axis",
#     "exclude_mask": "exclude_mask",
#     "ignore_index": "ignore_index",
#     "output": "output",
#     "target": "label",
#     "topk": "topk",
#     "x": "image"
# }
# { CrossEntropyLoss: 2.29, total_losses: 2.29 }
# model 0     Step: 8ms      | Loss: 2.28 | accuracy: 23.438%  | lr: 1.000e-03  | epoch: 0  ( 100/1000 )
# model 0     Step: 8ms      | Loss: 2.26 | accuracy: 21.875%  | lr: 1.000e-03  | epoch: 0  ( 200/1000 )
# model 0     Step: 7ms      | Loss: 2.23 | accuracy: 24.740%  | lr: 1.000e-03  | epoch: 0  ( 300/1000 )
# model 0     Step: 6ms      | Loss: 2.19 | accuracy: 27.539%  | lr: 1.000e-03  | epoch: 0  ( 400/1000 )
# model 0     Step: 6ms      | Loss: 2.17 | accuracy: 27.969%  | lr: 1.000e-03  | epoch: 0  ( 500/1000 )
# model 0     Step: 7ms      | Loss: 2.13 | accuracy: 28.385%  | lr: 1.000e-03  | epoch: 0  ( 600/1000 )
# model 0     Step: 7ms      | Loss: 2.07 | accuracy: 28.237%  | lr: 1.000e-03  | epoch: 0  ( 700/1000 )
# model 0     Step: 6ms      | Loss: 2.02 | accuracy: 27.637%  | lr: 1.000e-03  | epoch: 0  ( 800/1000 )
# model 0     Step: 7ms      | Loss: 1.98 | accuracy: 27.431%  | lr: 1.000e-03  | epoch: 0  ( 900/1000 )
# 最低 loss 1.8365e+00  最佳 metrics 35.9375%  最後10次 metrics 27.4306%
# 正常樣本 accuracy 28.1172%  DIFF: 0.6866%
# 噪聲樣本 accuracy 28.6250%  DIFF: 1.1944%

# %%
test_activity_function('gelu')
# Out:
# gelu
# 3.235401 sec
# CrossEntropyLoss( output: Tensor[(None,)] , target: Tensor[(None,)] ) -> loss: Tensor[(None,)]
# accuracy( output: Tensor[(None,)] , target: Tensor[(None,)] , topk: int =1, axis: int =1, ignore_index: int =-100, exclude_mask: bool =False) -> output: Tensor[(None,)]
# data_feed for model 0 :
# {
#     "axis": "axis",
#     "exclude_mask": "exclude_mask",
#     "ignore_index": "ignore_index",
#     "output": "output",
#     "target": "label",
#     "topk": "topk",
#     "x": "image"
# }
# { CrossEntropyLoss: 2.3, total_losses: 2.3 }
# model 0     Step: 7ms      | Loss: 2.28 | accuracy: 8.594%  | lr: 1.000e-03  | epoch: 0  ( 100/1000 )
# model 0     Step: 7ms      | Loss: 2.27 | accuracy: 12.500%  | lr: 1.000e-03  | epoch: 0  ( 200/1000 )
# model 0     Step: 7ms      | Loss: 2.25 | accuracy: 14.844%  | lr: 1.000e-03  | epoch: 0  ( 300/1000 )
# model 0     Step: 6ms      | Loss: 2.23 | accuracy: 17.773%  | lr: 1.000e-03  | epoch: 0  ( 400/1000 )
# model 0     Step: 6ms      | Loss: 2.21 | accuracy: 20.156%  | lr: 1.000e-03  | epoch: 0  ( 500/1000 )
# model 0     Step: 6ms      | Loss: 2.18 | accuracy: 23.177%  | lr: 1.000e-03  | epoch: 0  ( 600/1000 )
# model 0     Step: 6ms      | Loss: 2.15 | accuracy: 24.442%  | lr: 1.000e-03  | epoch: 0  ( 700/1000 )
# model 0     Step: 6ms      | Loss: 2.12 | accuracy: 26.562%  | lr: 1.000e-03  | epoch: 0  ( 800/1000 )
# model 0     Step: 7ms      | Loss: 2.06 | accuracy: 28.385%  | lr: 1.000e-03  | epoch: 0  ( 900/1000 )
# 最低 loss 1.9735e+00  最佳 metrics 42.9688%  最後10次 metrics 28.3854%
# 正常樣本 accuracy 48.0781%  DIFF: 19.6927%
# 噪聲樣本 accuracy 49.8750%  DIFF: 21.4896%

# %%
test_activity_function('SIREN')
# Out:
# SIREN
# 3.739960 sec
# CrossEntropyLoss( output: Tensor[(None,)] , target: Tensor[(None,)] ) -> loss: Tensor[(None,)]
# accuracy( output: Tensor[(None,)] , target: Tensor[(None,)] , topk: int =1, axis: int =1, ignore_index: int =-100, exclude_mask: bool =False) -> output: Tensor[(None,)]
# data_feed for model 0 :
# {
#     "axis": "axis",
#     "exclude_mask": "exclude_mask",
#     "ignore_index": "ignore_index",
#     "output": "output",
#     "target": "label",
#     "topk": "topk",
#     "x": "image"
# }
# { CrossEntropyLoss: 2.27, total_losses: 2.27 }
# model 0     Step: 6ms      | Loss: 2.18 | accuracy: 23.438%  | lr: 1.000e-03  | epoch: 0  ( 100/1000 )
# model 0     Step: 5ms      | Loss: 2.09 | accuracy: 28.516%  | lr: 1.000e-03  | epoch: 0  ( 200/1000 )
# model 0     Step: 5ms      | Loss: 1.99 | accuracy: 32.552%  | lr: 1.000e-03  | epoch: 0  ( 300/1000 )
# model 0     Step: 6ms      | Loss: 1.93 | accuracy: 35.742%  | lr: 1.000e-03  | epoch: 0  ( 400/1000 )
# model 0     Step: 6ms      | Loss: 1.84 | accuracy: 38.125%  | lr: 1.000e-03  | epoch: 0  ( 500/1000 )
# model 0     Step: 6ms      | Loss: 1.75 | accuracy: 41.927%  | lr: 1.000e-03  | epoch: 0  ( 600/1000 )
# model 0     Step: 6ms      | Loss: 1.69 | accuracy: 44.420%  | lr: 1.000e-03  | epoch: 0  ( 700/1000 )
# model 0     Step: 6ms      | Loss: 1.62 | accuracy: 45.508%  | lr: 1.000e-03  | epoch: 0  ( 800/1000 )
# model 0     Step: 6ms      | Loss: 1.57 | accuracy: 47.396%  | lr: 1.000e-03  | epoch: 0  ( 900/1000 )
# 最低 loss 1.4597e+00  最佳 metrics 62.5000%  最後10次 metrics 47.3958%
# 正常樣本 accuracy 62.7500%  DIFF: 15.3542%
# 噪聲樣本 accuracy 64.3750%  DIFF: 16.9792%

# %% [markdown]
# 首先要來看的是這幾個活化函數的計算開銷，我們紀錄每個活化函數各執行1萬次的執行時間長度，我們可以發現gelu的計算開銷是遠大於其他活化函數的。接下來我們想要看看這些模型實際面對測試數據以及面臨到數據品質極差的樣本時，是不是具有足夠的泛化能力。這邊可以看到新生代的活化函數整體上看來，泛化能力是排後段班的。
#
# 接下來我們將收集的梯度與權重歷程(我們是設定collect_data_inteval=100，即每100批次收集一次數據)，首先是看梯度分布的狀況，由於這個直方圖的z軸高度是根據圖表的最大值設定的，因此如果你看到有些圖看起來梯度很稀疏，幾乎看不到紅色區域，那就是它的梯度都集中在特定點(通常是0)，你可以看到relu是全部中梯度為零比例最高者，leaky_relu看起來很有效的緩解了relu梯度為零的缺陷，新生代的活化函數的梯度為零比率看起來表現尚可。
#
# 整體來看，新舊各有優點，老實說活化函數的影響其實低於優化器或者是權重初始化，若要我給個結論，我會建議的是：「別再使用relu了，如果你習慣傳統活化函數的低計算開銷，建議改成leaky_relu，如果你想嘗試新的活化函數，selu看起來是比較好的選擇」

# %%
# !pip install pandas
import pandas
#將performance_dict轉成表格
pd=pandas.DataFrame.from_dict(performance_dict)
pd
# Out:
# Collecting pandas
#   Downloading pandas-1.3.2-cp37-cp37m-win_amd64.whl (10.0 MB)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\jerryold\anaconda3\envs\test2\lib\site-packages (from pandas) (1.21.2)
# Collecting pytz>=2017.3
#   Using cached pytz-2021.1-py2.py3-none-any.whl (510 kB)
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'c:\\users\\jerryold\\anaconda3\\envs\\test2\\lib\\site-packages\\numpy-1.21.2.dist-info\\METADATA'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26364/1433993394.py in <module>
#       1 get_ipython().system('pip install pandas')
# ----> 2 import pandas
#       3 #將performance_dict轉成表格
#       4 pd=pandas.DataFrame.from_dict(performance_dict)
#       5 pd
#
# ModuleNotFoundError: No module named 'pandas'
